# %%
import pyodbc
import pandas as pd
from datetime import datetime
from scipy.stats import weibull_min
from scipy.stats import power_divergence

from settings import DEBUG,DATADIR,DATAFILE,DSTYPE,MINGAPSIZE_DAYS,MINGAPSIZE_HOURS
from helper import sql_data, save_df, shorten_rfg

ALL_DATA = pd.DataFrame()
ALL_DATA.name = "ALL_DATA"
if DSTYPE == 'File' :
    ALL_DATA = pd.read_csv(DATADIR + DATAFILE)  #Read all the data
elif DSTYPE == 'Database':
    ALL_DATA = sql_data()

try:
   ALL_DATA = ALL_DATA.drop(columns = ['RELEVANT_BEG_AGE.1','Unnamed: 0'])  # store as pkl and remove extra RELEVANT_BEG_AGE from sql
except:
    print("Superfluous columns removed already")
ALL_DATA.EVENT_DATE_TIME = pd.to_datetime(ALL_DATA.EVENT_DATE_TIME)


ALL_DATA.sort_values(by=['EI_SN','EVENT_DATE_TIME','RELEVANT_BEG_AGE'],inplace=True,ignore_index=True)   ## best bet on Sort by as all the bad data will end up at the 'end' of the day
ALL_DATA['EI_SN'] = ALL_DATA['EI_SN'].astype(str) # This just naturally wants to be an integer.  Thought about Pre-Pending a TN on it.
save_df(ALL_DATA)



# Use the Existing ALL_DATA frame to filter the result set instead of going back to the DB.
FILTERED_DATA = ALL_DATA[
                            (ALL_DATA['SCD2'] != 'X') & 
                            (ALL_DATA['SCD3'] != 'N') & 
                            (ALL_DATA['SCD5'] != 'N')
                        ]
FILTERED_DATA.name = "FILTERED_DATA"  # used to be the AH64E_2013toPres_SCORED.csv  
save_df(FILTERED_DATA)

#  No need for these to be pulled from the SQL.   
AH64E_TailNumList = FILTERED_DATA['EI_SN'].unique()        
AH64E_RFGList     = FILTERED_DATA['RFG'].unique()    #** maybe
AH64E_SCD1List    = FILTERED_DATA['SCD1'].unique()



################################
# Get Gaps per Tail Number
################################
GapFrame = ALL_DATA.copy() #work with a copy, not the orig
GapFrame = GapFrame.drop(columns = ['MAL_EFF', 'CORR_DATE_TIME', 'EI_CORR_AGE', 
                                    'TMMH', 'TMEN', 'TIMH', 'in_phase', 'in_qc', 
                                    'RFG', 'SCD1', 'SCD2', 'SCD3', 'SCD4', 'SCD5', 
                                    'SCD6', 'SCD7', 'SCD8', 'SCD9', 'PRIMARY_EVENT'])
# These next lines can be safely removed
# The original had extra Relevant Beg Age in the query, and storing as CSV gives unnamed instead of index
try:
   GapFrame = GapFrame.drop(columns = ['RELEVANT_BEG_AGE.1','Unnamed: 0'])  # store as pkl and remove extra RELEVANT_BEG_AGE from sql will remove this need
except:
    print("Superfluous columns removed already")

# Convert to Datetime to simplify the calculation.   
GapFrame.EVENT_DATE_TIME = pd.to_datetime(GapFrame.EVENT_DATE_TIME) #Seems to work without error on this dataset.  Will see if it continues

# Let's find the gaps on a per-aircraft basis.  groupby lets us perform the operations by the aircraft
# Add a date difference column and give the difference between this date and the last

GapFrame['datediff']  = GapFrame.groupby('EI_SN')['EVENT_DATE_TIME'].diff() 
# Same for the Flight Hours
GapFrame['hoursdiff'] = GapFrame.groupby('EI_SN')['RELEVANT_BEG_AGE'].diff()

# Add previous hours and date to this row so that we can visually compare.  Not strictly necessary
# but we can use this for debugging later if we want.
GapFrame['previous_date'] = GapFrame.groupby('EI_SN')['EVENT_DATE_TIME'].shift(1)
GapFrame['previous_hours'] = GapFrame.groupby('EI_SN')['RELEVANT_BEG_AGE'].shift(1)

# Filter the GapFrame by min Gap Size *and* min Gap hours (Settings.py).   Save the result to a pkl (saves more of the structure of the Dataframe with column types) 
# Add/change the save types by adjusting the helper library for save_df
TN_GAP_FRAME = GapFrame[
               ((GapFrame.datediff >= pd.Timedelta(str(MINGAPSIZE_DAYS) +  ' days')) & 
                (abs(GapFrame.hoursdiff) >= MINGAPSIZE_HOURS)) ]

GAPS = TN_GAP_FRAME[['EI_SN','previous_date','EVENT_DATE_TIME']]
GAPS = GAPS.rename(columns={"previous_date":'StartGap','EVENT_DATE_TIME':'EndGap'})
GAPS.reset_index(inplace=True) # I throw this in just about everywhere
GAPS.name = 'GAPS'
save_df(GAPS)

#################################################
# Get Usable Intervals from Gaps per Tail Number
#################################################

Intervals = pd.DataFrame()
groups = TN_GAP_FRAME.groupby('EI_SN').groups.keys() #Tail Numbers are the groups
for group in groups :
    # Filter the original dataset to just the tailnumbers we care about and then add a row.
    # We're inverting the gaps to get usable interval for each AC.
    # Gaps = 
    # [previous_date1,EVENT_DATE_TIME1], [previous_date2,EVENT_DATE_TIME2],[previous_date3,EVENT_DATE_TIME3].....
    # So Non-Gaps = 
    # [Min(EVENT_DATE_TIME),previous_date1],[EVENT_DATE_TIME1,previous_date2],[EVENT_DATE_TIME2,previous_date3],[EVENT_DATE_TIME3,max(EVENT_DATE_TIME)].....
    #
    tmpdf = TN_GAP_FRAME[TN_GAP_FRAME['EI_SN']==group]        # Filter by TN
    extrarowdf = tmpdf.iloc[-1:]                              # Copy last row
    tmpdf = pd.concat([tmpdf,extrarowdf], ignore_index=True)  # Add the copy to the end
    tmpdf['StartDtTm'] = tmpdf['EVENT_DATE_TIME'].shift(1)    # Shift the EVENT_DATE_TIME back one.
    tmpdf['EndDtTm']   = tmpdf['previous_date']               # 
    tmpdf['TailNumber'] = tmpdf['EI_SN'].astype('string')
    
    tmpdf.loc[0,'StartDtTm'] = GapFrame[GapFrame['EI_SN'] == group]['EVENT_DATE_TIME'].min() #             Min(EVENT_DATE_TIME)
    tmpdf.loc[tmpdf.index[-1],'EndDtTm'] = GapFrame[GapFrame['EI_SN'] == group]['EVENT_DATE_TIME'].max() # Max(EVENT_DATE_TIME)

    Intervals = pd.concat([Intervals,tmpdf[['TailNumber','StartDtTm','EndDtTm']]],ignore_index=True)  #add each TN Non-Gaps to dataframe.


# Every TN without a gap also needs to be added.  
# For every TN that didn't have a gap, get the min/max time.
leftovers = list(set(AH64E_TailNumList) - set(groups))
for continuous_tn in leftovers:
    tmpdf = ALL_DATA[ALL_DATA['EI_SN']==continuous_tn] 
    tmpdf2 = {'TailNumber': continuous_tn, 'StartDtTm': tmpdf['EVENT_DATE_TIME'].min() , 'EndDtTm': tmpdf['EVENT_DATE_TIME'].max()}  
    Intervals = Intervals.append(tmpdf2, ignore_index=True)

Intervals.reset_index(inplace=True)
Intervals.drop('index',axis=1,inplace=True)
Intervals.name = 'Intervals'
save_df(Intervals)
# Out:
# Superfluous columns removed already

# %%
#################################################
# Group Usable Intervals and TNs (Treat each Interval/TN as a separate Helicopter)
# Create an 'alternate tn' so we have no gaps to work around
#################################################


TN_Intervals = ALL_DATA.copy()
#For each interval where we have data
for interval in Intervals.itertuples():
    # Find all records which match the tail and interval in the intervals
    # The syntax is fairly straightforward, but the line gets so long its better to write it like SQL
    TN_Intervals.loc[
        (TN_Intervals['EI_SN'].astype(str) == str(interval.TailNumber)) &           
        (interval.StartDtTm <= TN_Intervals['EVENT_DATE_TIME'] ) & 
        (TN_Intervals['EVENT_DATE_TIME'] <= interval.EndDtTm)         
                               , 'NewTailNumber'] = str(interval.TailNumber) + "_" + str(interval.Index)  #Create another TN but just for separation sake

# Now we have a different 'Tail Number' (NewTailNumber) for each TN/continuous time.  So we no longer have to worry about Gaps in the data.
TN_Intervals = TN_Intervals.sort_values(['NewTailNumber','EVENT_DATE_TIME','RELEVANT_BEG_AGE'])
TN_Intervals.reset_index(drop=True)

save_df(TN_Intervals)

# %%
###############################################
# Attemp to correct the data a bit.  


#Find when time was accidentally increased and then decreased to compensate.  
TN_Intervals['timedelta'] = TN_Intervals.groupby('NewTailNumber')['RELEVANT_BEG_AGE'].diff()  # Find all the timedeltas between events
TN_Intervals['dd'] = TN_Intervals.groupby('NewTailNumber')['timedelta'].rolling(2).sum().reset_index(0,drop=True)  # This will find every instance where a time bounced forward/back within 2 events. eith +n/-n or -n/+n
TN_Intervals = TN_Intervals.reset_index(drop=True) # Apply liberally to the forehead
TN_Intervals[(TN_Intervals['timedelta'] < 0) ]  # Should be 1393 are negative on first pass
# TN_Intervals.iloc[945 : 950]
#TN_Intervals.iloc[567661: 567667]
# Out:
#                                   KEY13    EI_SN EVENT_DATE_TIME  \
# 948     AH-64E-1009002-20170922-A-00001  1009002      2017-09-22
# 3454    AH-64E-1009002-20190516-A-00001  1009002      2019-05-16
# 8256    AH-64E-1009003-20140323-A-00001  1009003      2014-03-23
# 8262    AH-64E-1009003-20140324-A-00003  1009003      2014-03-24
# 8282    AH-64E-1009003-20140327-A-00001  1009003      2014-03-27
# ...                                 ...      ...             ...
# 558160  AH-64E-1803222-20191026-A-00110  1803222      2019-10-26
# 564035  AH-64E-1803241-20200508-A-00100  1803241      2020-05-08
# 567729  AH-64E-1903251-20200213-A-00100  1903251      2020-02-13
# 567867  AH-64E-1903256-20200106-A-00101  1903256      2020-01-06
# 568025  AH-64E-1903256-20200218-A-00100  1903256      2020-02-18
#
#         RELEVANT_BEG_AGE  MAL_EFF       CORR_DATE_TIME  EI_CORR_AGE  TMMH  \
# 948          5730.700195        1  2017-09-29 17:00:00  5737.899902   6.0
# 3454         5938.100098        1  2019-05-20 10:54:00  5953.899902   0.1
# 8256         3569.800049        1  2014-03-24 03:23:00  3569.800049   0.3
# 8262         3569.800049        2  2014-03-24 02:38:00  3569.800049   0.2
# 8282         3570.000000        1  2014-03-28 07:56:00  3570.000000   0.4
# ...                  ...      ...                  ...          ...   ...
# 558160         38.900002        1  2019-10-26 05:18:00    43.299999   1.0
# 564035        188.100006        1  2020-05-08 09:19:00     0.000000   1.0
# 567729         86.099998        1  2020-02-13 07:25:00    86.099998   0.5
# 567867         16.400000        1  2020-01-06 17:22:00     0.000000   0.4
# 568025         48.099998        1  2020-02-18 08:34:00    48.099998   0.3
#
#         TMEN  TIMH  ...  SCD4  SCD5 SCD6 SCD7 SCD8 SCD9  \
# 948      2.0   0.0  ...     D     S    N    N    N    N
# 3454     1.0   0.0  ...     E     S    N    N    N    N
# 8256     1.0   0.2  ...     C     S    N    N    N    N
# 8262     1.0   0.3  ...     D     S    N    N    N    N
# 8282     1.0   0.1  ...     C     S    N    N    N    N
# ...      ...   ...  ...   ...   ...  ...  ...  ...  ...
# 558160   1.0   0.0  ...     C     S    N    N    N    N
# 564035   1.0   0.0  ...     D     N    N    N    N    N
# 567729   1.0   0.0  ...     C     S    N    N    N    N
# 567867   1.0   0.1  ...     D     S    N    N    N    N
# 568025   1.0   0.2  ...     D     S    N    N    N    N
#
#                           PRIMARY_EVENT NewTailNumber  timedelta         dd
# 948                                 NaN   1009002_152  -4.199707  -4.199707
# 3454                                NaN   1009002_152  -2.299805  -2.299805
# 8256                                NaN     1009003_1  -0.199951  -0.199951
# 8262    AH-64E-1009003-20140320-A-00007     1009003_1  -0.199951  -0.199951
# 8282                                NaN     1009003_1  -5.800049  -1.600098
# ...                                 ...           ...        ...        ...
# 558160                              NaN   1803222_231  -1.899998  -0.500000
# 564035  AH-64E-1803241-20200504-A-00380   1803241_145  -4.000000  -4.000000
# 567729                              NaN   1903251_163  -3.000000  -3.000000
# 567867                              NaN   1903256_210  -8.700001  -8.700001
# 568025                              NaN   1903256_210 -21.599998 -21.599998
#
# [791 rows x 26 columns]

# %%
# Find all events where the timedelta > 0 (increased hours between events) but the sum of the last 2 = 0  (negative, then corrective positive)
pos_indexes = TN_Intervals[(TN_Intervals['dd'] == 0) & (TN_Intervals['timedelta'] > 0)].index  
#print(pos_indexes)
for idx in pos_indexes :
     TN_Intervals.loc[idx,'RELEVANT_BEG_AGE'] = TN_Intervals.loc[(idx-1),'RELEVANT_BEG_AGE']  #set n = n -1 

# Find all events where the timedelta < 0 (increased hours between events) but the sum of the last 2 = 0  (positive, then corrective negative)
neg_indexes = TN_Intervals[(TN_Intervals['dd'] == 0) & (TN_Intervals['timedelta'] < 0)].index  
#print(neg_indexes)
for idx in neg_indexes :
     TN_Intervals.loc[(idx-1),'RELEVANT_BEG_AGE'] = TN_Intervals.loc[(idx),'RELEVANT_BEG_AGE'] #set n -1 = n.

#After this, it looks like we've corrected all by about 796 entries.  As you will see, some of the intervals just 'moved', so we could rerun/recorrect, but we'll proceed for now.

# %%
# Let's examine a couple entries to make sure things are just weird...

TN_Intervals.iloc[568020 : 568030]    # 4 bad entries on 2/24   We can clean these up as well, but we'll let them go for now
#TN_Intervals.iloc[945: 955]   # looks like it was 2 errors 

#Iterating the above sum->diff->reindex->replace routine will eventually remove them all.
# Out:
#                                   KEY13    EI_SN EVENT_DATE_TIME  \
# 568020  AH-64E-1903256-20200213-W-00100  1903256      2020-02-13
# 568021  AH-64E-1903256-20200213-A-00100  1903256      2020-02-13
# 568022  AH-64E-1903256-20200213-A-00110  1903256      2020-02-13
# 568023  AH-64E-1903256-20200213-A-00130  1903256      2020-02-13
# 568024  AH-64E-1903256-20200213-A-00160  1903256      2020-02-13
# 568025  AH-64E-1903256-20200218-A-00100  1903256      2020-02-18
# 568026  AH-64E-1903256-20200218-W-00100  1903256      2020-02-18
# 568027  AH-64E-1903256-20200219-A-00100  1903256      2020-02-19
# 568028  AH-64E-1903256-20200220-A-00100  1903256      2020-02-20
# 568029  AH-64E-1903256-20200221-A-00100  1903256      2020-02-21
#
#         RELEVANT_BEG_AGE  MAL_EFF       CORR_DATE_TIME  EI_CORR_AGE  TMMH  \
# 568020         48.099998        1  2020-02-13 16:24:00    48.099998   0.6
# 568021         69.699997        1  2020-02-24 10:24:00    48.099998   0.5
# 568022         69.699997        1  2020-02-24 10:22:00    48.099998   0.5
# 568023         69.699997        1  2020-02-18 11:57:00    48.099998   0.1
# 568024         69.699997        1  2020-02-13 05:20:00     0.000000   0.3
# 568025         48.099998        1  2020-02-18 08:34:00    48.099998   0.3
# 568026         48.099998        1  2020-02-19 14:07:00    48.099998   1.0
# 568027         48.099998        1  2020-02-20 10:19:00    48.099998   1.0
# 568028         48.099998        1  2020-02-27 09:53:00    49.099998   0.3
# 568029         48.099998        1  2020-02-26 12:24:00    48.099998   0.3
#
#         TMEN  TIMH  ...  SCD4  SCD5 SCD6 SCD7 SCD8 SCD9  \
# 568020   2.0   0.0  ...     C     S    N    N    N    N
# 568021   1.0   0.0  ...     C     S    N    N    N    N
# 568022   1.0   0.0  ...     D     S    N    N    N    N
# 568023   1.0   0.1  ...     C     A    N    N    N    N
# 568024   1.0   0.0  ...     D     S    N    N    N    N
# 568025   1.0   0.2  ...     D     S    N    N    N    N
# 568026   1.0   0.0  ...     C     S    N    N    N    N
# 568027   2.0   0.0  ...     C     S    N    N    N    N
# 568028   1.0   0.0  ...     B     S    N    N    N    N
# 568029   1.0   0.0  ...     B     S    N    N    N    N
#
#                           PRIMARY_EVENT NewTailNumber  timedelta         dd
# 568020                              NaN   1903256_210   0.000000   0.000000
# 568021                              NaN   1903256_210  21.599998  21.599998
# 568022                              NaN   1903256_210   0.000000  21.599998
# 568023                              NaN   1903256_210   0.000000   0.000000
# 568024                              NaN   1903256_210   0.000000   0.000000
# 568025                              NaN   1903256_210 -21.599998 -21.599998
# 568026                              NaN   1903256_210   0.000000 -21.599998
# 568027  AH-64E-1903256-20200218-W-00100   1903256_210   0.000000   0.000000
# 568028                              NaN   1903256_210   0.000000   0.000000
# 568029                              NaN   1903256_210   0.000000   0.000000
#
# [10 rows x 26 columns]

# %%
#################################################
# Add Event Class to the Dataframe
#  This process ends up copying events that fall into each eventclass (ema,ma,maf,schedmaint,uma,unschedmaint)
#################################################

TN_Intervals_EventClass = TN_Intervals.copy()
try:
   TN_Intervals_EventClass = TN_Intervals_EventClass.drop(columns = ['RELEVANT_BEG_AGE.1','Unnamed: 0'])  # store as pkl and remove extra RELEVANT_BEG_AGE from sql
except:
    print("Superfluous columns removed already")
# Set all EventClasses according to SCD Rules
# Filter and save dataframe for each EventClass
#Essential Maintenance Action
TN_Intervals_EventClass.loc[((TN_Intervals_EventClass.SCD2 != 'N') & (TN_Intervals_EventClass.SCD2 != 'P') & (TN_Intervals_EventClass.SCD2 != 'X') & (TN_Intervals_EventClass.SCD2 != 'Z') & (TN_Intervals_EventClass.SCD2 != '')) & (TN_Intervals_EventClass.SCD3 == 'C') & (TN_Intervals_EventClass.SCD8 != 'N') & (TN_Intervals_EventClass.RFG != '36B'),'EventClass'] = 'EMA'
ema = TN_Intervals_EventClass[TN_Intervals_EventClass['EventClass'] == 'EMA']

#Mission Abors
TN_Intervals_EventClass.loc[(TN_Intervals_EventClass.SCD3 == 'C') & (TN_Intervals_EventClass.SCD4 != 'O') & (TN_Intervals_EventClass.SCD4 != 'H') & ((TN_Intervals_EventClass.SCD2 == 'J') | (TN_Intervals_EventClass.SCD2 == 'K') | (TN_Intervals_EventClass.SCD2 == 'C') | (TN_Intervals_EventClass.SCD2 == 'S') | (TN_Intervals_EventClass.SCD2 == 'W') | (TN_Intervals_EventClass.SCD2 == 'Q') | (TN_Intervals_EventClass.SCD2 == 'U')) & ((TN_Intervals_EventClass.SCD5 == '1') | (TN_Intervals_EventClass.SCD5 == '2') | (TN_Intervals_EventClass.SCD5 == '4')) & (TN_Intervals_EventClass.RFG != '36B'),'EventClass'] = 'MA'
ma = TN_Intervals_EventClass[TN_Intervals_EventClass['EventClass'] == 'MA']

#Mission Affecting Failure
TN_Intervals_EventClass.loc[((TN_Intervals_EventClass.SCD2 != 'D') & (TN_Intervals_EventClass.SCD2 != 'N') & (TN_Intervals_EventClass.SCD2 != 'P') & (TN_Intervals_EventClass.SCD2 != 'X') & (TN_Intervals_EventClass.SCD2 != 'Z') & (TN_Intervals_EventClass.SCD2 != '')) & (TN_Intervals_EventClass.SCD3 == 'C') & (TN_Intervals_EventClass.SCD8 != 'N') & (TN_Intervals_EventClass.SCD9 != 'N') & (TN_Intervals_EventClass.RFG != '36B'),'EventClass'] = 'MAF'
maf = TN_Intervals_EventClass[TN_Intervals_EventClass['EventClass'] == 'MAF']

TN_Intervals_EventClass.loc[(TN_Intervals_EventClass.SCD2 != 'X') & (TN_Intervals_EventClass.SCD3 == 'C') & (TN_Intervals_EventClass.SCD5 == 'S') & (TN_Intervals_EventClass.RFG != '36B'),'EventClass'] = 'SchedMaint'
schedmaint = TN_Intervals_EventClass[TN_Intervals_EventClass['EventClass'] == 'SchedMaint']

TN_Intervals_EventClass.loc[((TN_Intervals_EventClass.SCD2 != 'X') & (TN_Intervals_EventClass.SCD2 != 'Z')) & (TN_Intervals_EventClass.SCD3 == 'C') & ((TN_Intervals_EventClass.SCD5 != 'M') & (TN_Intervals_EventClass.SCD5 != 'R') & (TN_Intervals_EventClass.SCD5 != 'S')) & (TN_Intervals_EventClass.RFG != '36B'),'EventClass'] = 'UMA'
uma = TN_Intervals_EventClass[TN_Intervals_EventClass['EventClass'] == 'UMA']

TN_Intervals_EventClass.loc[(TN_Intervals_EventClass.SCD5 != 'S') & (TN_Intervals_EventClass.SCD2 != 'X') & (TN_Intervals_EventClass.SCD3 == 'C'),'EventClass'] = 'UnschedMaint'
unschedmaint = TN_Intervals_EventClass[TN_Intervals_EventClass['EventClass'] == 'UnschedMaint']

# Concatinate all the EventClasses into a big frame and remove the old frame
# Lots of events are in several of these lists, so we end up with more data/rows
TN_Intervals_EventClass = pd.concat([ema,ma,maf,schedmaint,uma,unschedmaint],ignore_index=True)

# The following section isn't needed since these fields aren't used, but was used to validate that the above code worked the same.
TN_Intervals_EventClass['Key13 / RFG / EventClass'] = TN_Intervals_EventClass.apply(lambda y: str(y.KEY13[:15] + y.RFG + '-' + y.EventClass + y.KEY13[14:]),axis=1)
TN_Intervals_EventClass = TN_Intervals_EventClass.drop(['MAL_EFF', 'CORR_DATE_TIME', 'EI_CORR_AGE', 'in_phase', 'in_qc', 'SCD1','SCD2', 'SCD3', 'SCD4', 'SCD5', 'SCD6', 'SCD7', 'SCD8', 'SCD9', 'PRIMARY_EVENT'], axis=1)
TN_Intervals_EventClass = TN_Intervals_EventClass.sort_values(['Key13 / RFG / EventClass'])
TN_Intervals_EventClass = TN_Intervals_EventClass.reset_index(drop=True)
TN_Intervals_EventClass['lengthRFG'] = TN_Intervals_EventClass.apply(lambda y :len(y['RFG']), axis=1)
TN_Intervals_EventClass = TN_Intervals_EventClass.rename(columns={'EI_SN':'TailNumber'})

# This field is needed in the following section
TN_Intervals_EventClass['tn-class'] = TN_Intervals_EventClass['NewTailNumber'].astype(str) + "-" + TN_Intervals_EventClass['EventClass']


TN_Intervals_EventClass = TN_Intervals_EventClass[['Key13 / RFG / EventClass','KEY13','TailNumber','NewTailNumber','tn-class','EVENT_DATE_TIME','RELEVANT_BEG_AGE','TMMH','TMEN','TIMH','RFG','EventClass','lengthRFG']]
TN_Intervals_EventClass.name = "TN_Intervals_EventClass"
# Validation file save
# TN_Intervals_EventClass.to_csv(output_dir + 'AH64E_NewId_2013toPres_SCORED.csv')
save_df(TN_Intervals_EventClass)
# Out:
# Superfluous columns removed already

# %%
################################################
# Shorten RFGs
#    For each TN/EventClass/Interval do: 
#      Count RFGs
#      While Exists RFG with 1 value :
#         For each RFG with only 1 value, shorten
#  This is the long pole in the tent as it has to be shortened per-RFG/class/TN so we have an interval
#  
#  This is the longest run.  10m 11 seconds last run.

pd.options.mode.chained_assignment = None  # Supress Warnings.
Shortened_RFGs = TN_Intervals_EventClass.copy()

#  Here we take each 'Tail Number' and we look over the RFGs.
#  If we find some single RFGs, then we reduce and see if we find match 'above' us in the RFG Chain.   We continue to do this until we are either 2 digits *or* we have more than 1 (1 good interval!)
print("Total tailnumbers & classes : " + str(len(Shortened_RFGs["tn-class"].unique())))
i = 1
for tn in Shortened_RFGs["tn-class"].unique() :  
    tmpframe = Shortened_RFGs[Shortened_RFGs['tn-class']==tn]  #Create a temporary frame with just the tail number/interval I'm interested in
    # This while loop has 2 conditions.  
    #    a)  There existing at least 1 RFG in the tmpframe with only 1 entry 
    #    b)  The max length of RFG(s) with one entry is greater than 2 (if the max length was 2, then we can no longer trim)
    print ("Shortening  for TN:  " + str(tn) + " " + "loop count" + str(i))
    while ((tmpframe[tmpframe['RFG'].map(tmpframe['RFG'].value_counts()) == 1 ].shape[0] > 0) & (tmpframe[tmpframe['RFG'].map(tmpframe['RFG'].value_counts()) == 1 ]['RFG'].map(len).max() > 2 )):
        # Shorten the RFGs!
        tmpframe.loc[tmpframe['RFG'].map(tmpframe['RFG'].value_counts()) == 1, 'RFG'] = tmpframe.loc[tmpframe['RFG'].map(tmpframe['RFG'].value_counts()) == 1]['RFG'].apply(lambda y : shorten_rfg(y)) # over in helper methods
    Shortened_RFGs.update(tmpframe) #Update our Shortened RFGs
    Shortened_RFGs['tn-class'] = Shortened_RFGs['NewTailNumber'].astype(str) + "-" + Shortened_RFGs['EventClass']
    i = i + 1

#################################
#  So there is an edge case where shortened RFGs can converge to a non-existent RFG (assuming not all chains shorten the same way) however, verifying that the RFGs converge to 
#  *something* or the 2 digit starting Functional group, should make it rare if at all.  This can be changed by simply building the RFG structure and decrimenting down the tree which will be marginally slower (maybe)

save_df(Shortened_RFGs)
# Out:
# Total tailnumbers & classes : 1490
# Shortening  for TN:  1009002_152-SchedMaint loop count1
# Shortening  for TN:  1009002_152-UMA loop count2
# Shortening  for TN:  1009002_152-UnschedMaint loop count3
# Shortening  for TN:  1009002_152-EMA loop count4
# Shortening  for TN:  1009002_152-MA loop count5
# Shortening  for TN:  1009002_152-MAF loop count6
# Shortening  for TN:  1009003_2-EMA loop count7
# Shortening  for TN:  1009003_2-MA loop count8
# Shortening  for TN:  1009003_2-MAF loop count9
# Shortening  for TN:  1009003_0-SchedMaint loop count10
# Shortening  for TN:  1009003_1-SchedMaint loop count11
# Shortening  for TN:  1009003_2-SchedMaint loop count12
# Shortening  for TN:  1009003_0-UMA loop count13
# Shortening  for TN:  1009003_1-UMA loop count14
# Shortening  for TN:  1009003_2-UMA loop count15
# Shortening  for TN:  1009003_0-UnschedMaint loop count16
# Shortening  for TN:  1009003_1-UnschedMaint loop count17
# Shortening  for TN:  1009003_2-UnschedMaint loop count18
# Shortening  for TN:  1009003_0-EMA loop count19
# Shortening  for TN:  1009003_1-EMA loop count20
# Shortening  for TN:  1009003_1-MAF loop count21
# Shortening  for TN:  1009003_0-MA loop count22
# Shortening  for TN:  1009003_0-MAF loop count23
# Shortening  for TN:  1009003_1-MA loop count24
# Shortening  for TN:  1009004_5-EMA loop count25
# Shortening  for TN:  1009004_5-MA loop count26
# Shortening  for TN:  1009004_5-MAF loop count27
# Shortening  for TN:  1009004_3-SchedMaint loop count28
# Shortening  for TN:  1009004_4-SchedMaint loop count29
# Shortening  for TN:  1009004_5-SchedMaint loop count30
# Shortening  for TN:  1009004_3-UMA loop count31
# Shortening  for TN:  1009004_4-UMA loop count32
# Shortening  for TN:  1009004_5-UMA loop count33
# Shortening  for TN:  1009004_3-UnschedMaint loop count34
# Shortening  for TN:  1009004_4-UnschedMaint loop count35
# Shortening  for TN:  1009004_5-UnschedMaint loop count36
# Shortening  for TN:  1009004_3-EMA loop count37
# Shortening  for TN:  1009004_4-EMA loop count38
# Shortening  for TN:  1009004_4-MAF loop count39
# Shortening  for TN:  1009004_4-MA loop count40
# Shortening  for TN:  1009004_3-MA loop count41
# Shortening  for TN:  1009004_3-MAF loop count42
# Shortening  for TN:  1009005_8-EMA loop count43
# Shortening  for TN:  1009005_6-SchedMaint loop count44
# Shortening  for TN:  1009005_7-SchedMaint loop count45
# Shortening  for TN:  1009005_8-SchedMaint loop count46
# Shortening  for TN:  1009005_6-UMA loop count47
# Shortening  for TN:  1009005_7-UMA loop count48
# Shortening  for TN:  1009005_8-UMA loop count49
# Shortening  for TN:  1009005_6-UnschedMaint loop count50
# Shortening  for TN:  1009005_7-UnschedMaint loop count51
# Shortening  for TN:  1009005_8-UnschedMaint loop count52
# Shortening  for TN:  1009005_7-EMA loop count53
# Shortening  for TN:  1009005_6-EMA loop count54
# Shortening  for TN:  1009005_6-MAF loop count55
# Shortening  for TN:  1009005_8-MAF loop count56
# Shortening  for TN:  1009005_8-MA loop count57
# Shortening  for TN:  1009005_6-MA loop count58
# Shortening  for TN:  1009005_7-MA loop count59
# Shortening  for TN:  1009005_7-MAF loop count60
# Shortening  for TN:  1009006_9-EMA loop count61
# Shortening  for TN:  1009006_10-EMA loop count62
# Shortening  for TN:  1009006_9-MA loop count63
# Shortening  for TN:  1009006_9-MAF loop count64
# Shortening  for TN:  1009006_9-SchedMaint loop count65
# Shortening  for TN:  1009006_10-SchedMaint loop count66
# Shortening  for TN:  1009006_9-UMA loop count67
# Shortening  for TN:  1009006_10-UMA loop count68
# Shortening  for TN:  1009006_9-UnschedMaint loop count69
# Shortening  for TN:  1009006_10-UnschedMaint loop count70
# Shortening  for TN:  1009006_10-MAF loop count71
# Shortening  for TN:  1009006_10-MA loop count72
# Shortening  for TN:  1009007_12-EMA loop count73
# Shortening  for TN:  1009007_13-EMA loop count74
# Shortening  for TN:  1009007_13-MAF loop count75
# Shortening  for TN:  1009007_11-SchedMaint loop count76
# Shortening  for TN:  1009007_12-SchedMaint loop count77
# Shortening  for TN:  1009007_13-SchedMaint loop count78
# Shortening  for TN:  1009007_11-UMA loop count79
# Shortening  for TN:  1009007_12-UMA loop count80
# Shortening  for TN:  1009007_13-UMA loop count81
# Shortening  for TN:  1009007_11-UnschedMaint loop count82
# Shortening  for TN:  1009007_12-UnschedMaint loop count83
# Shortening  for TN:  1009007_13-UnschedMaint loop count84
# Shortening  for TN:  1009007_11-EMA loop count85
# Shortening  for TN:  1009007_13-MA loop count86
# Shortening  for TN:  1009007_12-MA loop count87
# Shortening  for TN:  1009007_12-MAF loop count88
# Shortening  for TN:  1009007_11-MAF loop count89
# Shortening  for TN:  1009007_11-MA loop count90
# Shortening  for TN:  1009008_158-SchedMaint loop count91
# Shortening  for TN:  1009008_158-UMA loop count92
# Shortening  for TN:  1009008_158-UnschedMaint loop count93
# Shortening  for TN:  1009008_158-EMA loop count94
# Shortening  for TN:  1009008_158-MAF loop count95
# Shortening  for TN:  1009008_158-MA loop count96
# Shortening  for TN:  1109009_15-EMA loop count97
# Shortening  for TN:  1109009_15-MA loop count98
# Shortening  for TN:  1109009_15-MAF loop count99
# Shortening  for TN:  1109009_14-SchedMaint loop count100
# Shortening  for TN:  1109009_15-SchedMaint loop count101
# Shortening  for TN:  1109009_14-UMA loop count102
# Shortening  for TN:  1109009_15-UMA loop count103
# Shortening  for TN:  1109009_14-UnschedMaint loop count104
# Shortening  for TN:  1109009_15-UnschedMaint loop count105
# Shortening  for TN:  1109009_14-EMA loop count106
# Shortening  for TN:  1109009_14-MA loop count107
# Shortening  for TN:  1109009_14-MAF loop count108
# Shortening  for TN:  1109010_218-EMA loop count109
# Shortening  for TN:  1109010_218-SchedMaint loop count110
# Shortening  for TN:  1109010_218-UMA loop count111
# Shortening  for TN:  1109010_218-UnschedMaint loop count112
# Shortening  for TN:  1109010_218-MA loop count113
# Shortening  for TN:  1109010_218-MAF loop count114
# Shortening  for TN:  1109011_18-EMA loop count115
# Shortening  for TN:  1109011_16-SchedMaint loop count116
# Shortening  for TN:  1109011_17-SchedMaint loop count117
# Shortening  for TN:  1109011_18-SchedMaint loop count118
# Shortening  for TN:  1109011_19-SchedMaint loop count119
# Shortening  for TN:  1109011_16-UMA loop count120
# Shortening  for TN:  1109011_17-UMA loop count121
# Shortening  for TN:  1109011_18-UMA loop count122
# Shortening  for TN:  1109011_19-UMA loop count123
# Shortening  for TN:  1109011_16-UnschedMaint loop count124
# Shortening  for TN:  1109011_17-UnschedMaint loop count125
# Shortening  for TN:  1109011_18-UnschedMaint loop count126
# Shortening  for TN:  1109011_19-UnschedMaint loop count127
# Shortening  for TN:  1109011_17-EMA loop count128
# Shortening  for TN:  1109011_19-EMA loop count129
# Shortening  for TN:  1109011_16-EMA loop count130
# Shortening  for TN:  1109011_18-MA loop count131
# Shortening  for TN:  1109011_18-MAF loop count132
# Shortening  for TN:  1109011_16-MAF loop count133
# Shortening  for TN:  1109011_16-MA loop count134
# Shortening  for TN:  1109011_19-MA loop count135
# Shortening  for TN:  1109011_19-MAF loop count136
# Shortening  for TN:  1109011_17-MAF loop count137
# Shortening  for TN:  1109011_17-MA loop count138
# Shortening  for TN:  1109012_20-EMA loop count139
# Shortening  for TN:  1109012_20-MAF loop count140
# Shortening  for TN:  1109012_20-SchedMaint loop count141
# Shortening  for TN:  1109012_21-SchedMaint loop count142
# Shortening  for TN:  1109012_20-UMA loop count143
# Shortening  for TN:  1109012_20-UnschedMaint loop count144
# Shortening  for TN:  1109012_21-UMA loop count145
# Shortening  for TN:  1109012_21-UnschedMaint loop count146
# Shortening  for TN:  1109012_21-EMA loop count147
# Shortening  for TN:  1109012_21-MA loop count148
# Shortening  for TN:  1109012_21-MAF loop count149
# Shortening  for TN:  1109012_20-MA loop count150
# Shortening  for TN:  1109013_22-SchedMaint loop count151
# Shortening  for TN:  1109013_23-SchedMaint loop count152
# Shortening  for TN:  1109013_22-UMA loop count153
# Shortening  for TN:  1109013_22-UnschedMaint loop count154
# Shortening  for TN:  1109013_23-EMA loop count155
# Shortening  for TN:  1109013_23-UMA loop count156
# Shortening  for TN:  1109013_23-UnschedMaint loop count157
# Shortening  for TN:  1109013_22-EMA loop count158
# Shortening  for TN:  1109013_22-MAF loop count159
# Shortening  for TN:  1109013_22-MA loop count160
# Shortening  for TN:  1109014_26-EMA loop count161
# Shortening  for TN:  1109014_24-SchedMaint loop count162
# Shortening  for TN:  1109014_25-SchedMaint loop count163
# Shortening  for TN:  1109014_26-SchedMaint loop count164
# Shortening  for TN:  1109014_24-UMA loop count165
# Shortening  for TN:  1109014_25-UMA loop count166
# Shortening  for TN:  1109014_26-UMA loop count167
# Shortening  for TN:  1109014_24-UnschedMaint loop count168
# Shortening  for TN:  1109014_25-UnschedMaint loop count169
# Shortening  for TN:  1109014_26-UnschedMaint loop count170
# Shortening  for TN:  1109014_25-EMA loop count171
# Shortening  for TN:  1109014_24-EMA loop count172
# Shortening  for TN:  1109014_25-MA loop count173
# Shortening  for TN:  1109014_25-MAF loop count174
# Shortening  for TN:  1109014_26-MAF loop count175
# Shortening  for TN:  1109014_26-MA loop count176
# Shortening  for TN:  1109014_24-MAF loop count177
# Shortening  for TN:  1109016_27-EMA loop count178
# Shortening  for TN:  1109016_28-EMA loop count179
# Shortening  for TN:  1109016_27-SchedMaint loop count180
# Shortening  for TN:  1109016_28-SchedMaint loop count181
# Shortening  for TN:  1109016_27-UMA loop count182
# Shortening  for TN:  1109016_28-UMA loop count183
# Shortening  for TN:  1109016_27-UnschedMaint loop count184
# Shortening  for TN:  1109016_28-UnschedMaint loop count185
# Shortening  for TN:  1109016_28-MAF loop count186
# Shortening  for TN:  1109016_28-MA loop count187
# Shortening  for TN:  1109016_27-MA loop count188
# Shortening  for TN:  1109016_27-MAF loop count189
# Shortening  for TN:  1109017_29-EMA loop count190
# Shortening  for TN:  1109017_30-EMA loop count191
# Shortening  for TN:  1109017_29-MA loop count192
# Shortening  for TN:  1109017_29-MAF loop count193
# Shortening  for TN:  1109017_29-SchedMaint loop count194
# Shortening  for TN:  1109017_30-SchedMaint loop count195
# Shortening  for TN:  1109017_31-SchedMaint loop count196
# Shortening  for TN:  1109017_29-UMA loop count197
# Shortening  for TN:  1109017_30-UMA loop count198
# Shortening  for TN:  1109017_31-UMA loop count199
# Shortening  for TN:  1109017_29-UnschedMaint loop count200
# Shortening  for TN:  1109017_30-UnschedMaint loop count201
# Shortening  for TN:  1109017_31-UnschedMaint loop count202
# Shortening  for TN:  1109017_31-EMA loop count203
# Shortening  for TN:  1109017_31-MA loop count204
# Shortening  for TN:  1109017_31-MAF loop count205
# Shortening  for TN:  1109017_30-MA loop count206
# Shortening  for TN:  1109017_30-MAF loop count207
# Shortening  for TN:  1109018_34-EMA loop count208
# Shortening  for TN:  1109018_32-SchedMaint loop count209
# Shortening  for TN:  1109018_33-SchedMaint loop count210
# Shortening  for TN:  1109018_34-SchedMaint loop count211
# Shortening  for TN:  1109018_35-SchedMaint loop count212
# Shortening  for TN:  1109018_32-UMA loop count213
# Shortening  for TN:  1109018_34-UMA loop count214
# Shortening  for TN:  1109018_35-UMA loop count215
# Shortening  for TN:  1109018_32-UnschedMaint loop count216
# Shortening  for TN:  1109018_34-UnschedMaint loop count217
# Shortening  for TN:  1109018_35-UnschedMaint loop count218
# Shortening  for TN:  1109018_35-EMA loop count219
# Shortening  for TN:  1109018_32-EMA loop count220
# Shortening  for TN:  1109018_33-UMA loop count221
# Shortening  for TN:  1109018_33-UnschedMaint loop count222
# Shortening  for TN:  1109018_33-EMA loop count223
# Shortening  for TN:  1109018_34-MA loop count224
# Shortening  for TN:  1109018_34-MAF loop count225
# Shortening  for TN:  1109018_33-MA loop count226
# Shortening  for TN:  1109018_33-MAF loop count227
# Shortening  for TN:  1109018_32-MAF loop count228
# Shortening  for TN:  1109018_35-MA loop count229
# Shortening  for TN:  1109018_35-MAF loop count230
# Shortening  for TN:  1109018_32-MA loop count231
# Shortening  for TN:  1109019_36-EMA loop count232
# Shortening  for TN:  1109019_38-EMA loop count233
# Shortening  for TN:  1109019_36-SchedMaint loop count234
# Shortening  for TN:  1109019_37-SchedMaint loop count235
# Shortening  for TN:  1109019_38-SchedMaint loop count236
# Shortening  for TN:  1109019_39-SchedMaint loop count237
# Shortening  for TN:  1109019_36-UMA loop count238
# Shortening  for TN:  1109019_37-UMA loop count239
# Shortening  for TN:  1109019_38-UMA loop count240
# Shortening  for TN:  1109019_36-UnschedMaint loop count241
# Shortening  for TN:  1109019_37-UnschedMaint loop count242
# Shortening  for TN:  1109019_38-UnschedMaint loop count243
# Shortening  for TN:  1109019_37-EMA loop count244
# Shortening  for TN:  1109019_39-EMA loop count245
# Shortening  for TN:  1109019_39-UMA loop count246
# Shortening  for TN:  1109019_39-UnschedMaint loop count247
# Shortening  for TN:  1109019_36-MA loop count248
# Shortening  for TN:  1109019_36-MAF loop count249
# Shortening  for TN:  1109019_38-MAF loop count250
# Shortening  for TN:  1109019_38-MA loop count251
# Shortening  for TN:  1109019_39-MAF loop count252
# Shortening  for TN:  1109019_39-MA loop count253
# Shortening  for TN:  1109019_37-MAF loop count254
# Shortening  for TN:  1109019_37-MA loop count255
# Shortening  for TN:  1109020_40-EMA loop count256
# Shortening  for TN:  1109020_41-EMA loop count257
# Shortening  for TN:  1109020_42-EMA loop count258
# Shortening  for TN:  1109020_42-MA loop count259
# Shortening  for TN:  1109020_41-MAF loop count260
# Shortening  for TN:  1109020_42-MAF loop count261
# Shortening  for TN:  1109020_40-SchedMaint loop count262
# Shortening  for TN:  1109020_41-SchedMaint loop count263
# Shortening  for TN:  1109020_42-SchedMaint loop count264
# Shortening  for TN:  1109020_40-UMA loop count265
# Shortening  for TN:  1109020_41-UMA loop count266
# Shortening  for TN:  1109020_42-UMA loop count267
# Shortening  for TN:  1109020_40-UnschedMaint loop count268
# Shortening  for TN:  1109020_41-UnschedMaint loop count269
# Shortening  for TN:  1109020_42-UnschedMaint loop count270
# Shortening  for TN:  1109020_40-MA loop count271
# Shortening  for TN:  1109020_40-MAF loop count272
# Shortening  for TN:  1109020_41-MA loop count273
# Shortening  for TN:  1109021_43-EMA loop count274
# Shortening  for TN:  1109021_45-EMA loop count275
# Shortening  for TN:  1109021_43-SchedMaint loop count276
# Shortening  for TN:  1109021_44-SchedMaint loop count277
# Shortening  for TN:  1109021_45-SchedMaint loop count278
# Shortening  for TN:  1109021_43-UMA loop count279
# Shortening  for TN:  1109021_44-UMA loop count280
# Shortening  for TN:  1109021_45-UMA loop count281
# Shortening  for TN:  1109021_43-UnschedMaint loop count282
# Shortening  for TN:  1109021_44-UnschedMaint loop count283
# Shortening  for TN:  1109021_45-UnschedMaint loop count284
# Shortening  for TN:  1109021_44-EMA loop count285
# Shortening  for TN:  1109021_43-MA loop count286
# Shortening  for TN:  1109021_43-MAF loop count287
# Shortening  for TN:  1109021_45-MA loop count288
# Shortening  for TN:  1109021_45-MAF loop count289
# Shortening  for TN:  1109021_44-MA loop count290
# Shortening  for TN:  1109021_44-MAF loop count291
# Shortening  for TN:  1109022_153-EMA loop count292
# Shortening  for TN:  1109022_153-MA loop count293
# Shortening  for TN:  1109022_153-MAF loop count294
# Shortening  for TN:  1109022_153-SchedMaint loop count295
# Shortening  for TN:  1109022_153-UMA loop count296
# Shortening  for TN:  1109022_153-UnschedMaint loop count297
# Shortening  for TN:  1109023_46-EMA loop count298
# Shortening  for TN:  1109023_47-EMA loop count299
# Shortening  for TN:  1109023_46-SchedMaint loop count300
# Shortening  for TN:  1109023_47-SchedMaint loop count301
# Shortening  for TN:  1109023_46-UMA loop count302
# Shortening  for TN:  1109023_47-UMA loop count303
# Shortening  for TN:  1109023_46-UnschedMaint loop count304
# Shortening  for TN:  1109023_47-UnschedMaint loop count305
# Shortening  for TN:  1109023_46-MA loop count306
# Shortening  for TN:  1109023_47-MA loop count307
# Shortening  for TN:  1109023_46-MAF loop count308
# Shortening  for TN:  1109023_47-MAF loop count309
# Shortening  for TN:  1109024_188-EMA loop count310
# Shortening  for TN:  1109024_188-SchedMaint loop count311
# Shortening  for TN:  1109024_188-UMA loop count312
# Shortening  for TN:  1109024_188-UnschedMaint loop count313
# Shortening  for TN:  1109024_188-MAF loop count314
# Shortening  for TN:  1109024_188-MA loop count315
# Shortening  for TN:  1209025_115-EMA loop count316
# Shortening  for TN:  1209025_115-SchedMaint loop count317
# Shortening  for TN:  1209025_115-UMA loop count318
# Shortening  for TN:  1209025_115-UnschedMaint loop count319
# Shortening  for TN:  1209025_115-MAF loop count320
# Shortening  for TN:  1209025_115-MA loop count321
# Shortening  for TN:  1209026_125-EMA loop count322
# Shortening  for TN:  1209026_125-SchedMaint loop count323
# Shortening  for TN:  1209026_125-UMA loop count324
# Shortening  for TN:  1209026_125-UnschedMaint loop count325
# Shortening  for TN:  1209026_125-MA loop count326
# Shortening  for TN:  1209026_125-MAF loop count327
# Shortening  for TN:  1209027_48-EMA loop count328
# Shortening  for TN:  1209027_49-EMA loop count329
# Shortening  for TN:  1209027_48-SchedMaint loop count330
# Shortening  for TN:  1209027_49-SchedMaint loop count331
# Shortening  for TN:  1209027_48-UMA loop count332
# Shortening  for TN:  1209027_49-UMA loop count333
# Shortening  for TN:  1209027_48-UnschedMaint loop count334
# Shortening  for TN:  1209027_49-UnschedMaint loop count335
# Shortening  for TN:  1209027_49-MA loop count336
# Shortening  for TN:  1209027_49-MAF loop count337
# Shortening  for TN:  1209027_48-MA loop count338
# Shortening  for TN:  1209027_48-MAF loop count339
# Shortening  for TN:  1209028_117-SchedMaint loop count340
# Shortening  for TN:  1209028_117-EMA loop count341
# Shortening  for TN:  1209028_117-UMA loop count342
# Shortening  for TN:  1209028_117-UnschedMaint loop count343
# Shortening  for TN:  1209028_117-MA loop count344
# Shortening  for TN:  1209028_117-MAF loop count345
# Shortening  for TN:  1209029_51-EMA loop count346
# Shortening  for TN:  1209029_50-SchedMaint loop count347
# Shortening  for TN:  1209029_51-SchedMaint loop count348
# Shortening  for TN:  1209029_50-UMA loop count349
# Shortening  for TN:  1209029_51-UMA loop count350
# Shortening  for TN:  1209029_50-UnschedMaint loop count351
# Shortening  for TN:  1209029_51-UnschedMaint loop count352
# Shortening  for TN:  1209029_50-EMA loop count353
# Shortening  for TN:  1209029_51-MA loop count354
# Shortening  for TN:  1209029_51-MAF loop count355
# Shortening  for TN:  1209029_50-MA loop count356
# Shortening  for TN:  1209029_50-MAF loop count357
# Shortening  for TN:  1209030_149-EMA loop count358
# Shortening  for TN:  1209030_149-SchedMaint loop count359
# Shortening  for TN:  1209030_149-UMA loop count360
# Shortening  for TN:  1209030_149-UnschedMaint loop count361
# Shortening  for TN:  1209030_149-MA loop count362
# Shortening  for TN:  1209030_149-MAF loop count363
# Shortening  for TN:  1209031_216-EMA loop count364
# Shortening  for TN:  1209031_216-SchedMaint loop count365
# Shortening  for TN:  1209031_216-UMA loop count366
# Shortening  for TN:  1209031_216-UnschedMaint loop count367
# Shortening  for TN:  1209031_216-MA loop count368
# Shortening  for TN:  1209031_216-MAF loop count369
# Shortening  for TN:  1209032_107-SchedMaint loop count370
# Shortening  for TN:  1209032_107-UMA loop count371
# Shortening  for TN:  1209032_107-UnschedMaint loop count372
# Shortening  for TN:  1209032_107-EMA loop count373
# Shortening  for TN:  1209032_107-MA loop count374
# Shortening  for TN:  1209032_107-MAF loop count375
# Shortening  for TN:  1209034_112-SchedMaint loop count376
# Shortening  for TN:  1209034_112-UMA loop count377
# Shortening  for TN:  1209034_112-UnschedMaint loop count378
# Shortening  for TN:  1209034_112-EMA loop count379
# Shortening  for TN:  1209034_112-MAF loop count380
# Shortening  for TN:  1209034_112-MA loop count381
# Shortening  for TN:  1209035_205-EMA loop count382
# Shortening  for TN:  1209035_205-MA loop count383
# Shortening  for TN:  1209035_205-MAF loop count384
# Shortening  for TN:  1209035_205-SchedMaint loop count385
# Shortening  for TN:  1209035_205-UMA loop count386
# Shortening  for TN:  1209035_205-UnschedMaint loop count387
# Shortening  for TN:  1209036_243-EMA loop count388
# Shortening  for TN:  1209036_243-MAF loop count389
# Shortening  for TN:  1209036_243-SchedMaint loop count390
# Shortening  for TN:  1209036_243-UMA loop count391
# Shortening  for TN:  1209036_243-UnschedMaint loop count392
# Shortening  for TN:  1209036_243-MA loop count393
# Shortening  for TN:  1209037_52-SchedMaint loop count394
# Shortening  for TN:  1209037_53-SchedMaint loop count395
# Shortening  for TN:  1209037_53-UMA loop count396
# Shortening  for TN:  1209037_53-UnschedMaint loop count397
# Shortening  for TN:  1209037_53-EMA loop count398
# Shortening  for TN:  1209037_52-EMA loop count399
# Shortening  for TN:  1209037_52-UMA loop count400
# Shortening  for TN:  1209037_52-UnschedMaint loop count401
# Shortening  for TN:  1209037_52-MA loop count402
# Shortening  for TN:  1209037_52-MAF loop count403
# Shortening  for TN:  1209037_53-MA loop count404
# Shortening  for TN:  1209037_53-MAF loop count405
# Shortening  for TN:  1209038_161-SchedMaint loop count406
# Shortening  for TN:  1209038_161-UMA loop count407
# Shortening  for TN:  1209038_161-UnschedMaint loop count408
# Shortening  for TN:  1209038_161-EMA loop count409
# Shortening  for TN:  1209038_161-MAF loop count410
# Shortening  for TN:  1209038_161-MA loop count411
# Shortening  for TN:  1209039_160-EMA loop count412
# Shortening  for TN:  1209039_160-MA loop count413
# Shortening  for TN:  1209039_160-MAF loop count414
# Shortening  for TN:  1209039_160-SchedMaint loop count415
# Shortening  for TN:  1209039_160-UMA loop count416
# Shortening  for TN:  1209039_160-UnschedMaint loop count417
# Shortening  for TN:  1209040_144-SchedMaint loop count418
# Shortening  for TN:  1209040_144-EMA loop count419
# Shortening  for TN:  1209040_144-UMA loop count420
# Shortening  for TN:  1209040_144-UnschedMaint loop count421
# Shortening  for TN:  1209040_144-MAF loop count422
# Shortening  for TN:  1209040_144-MA loop count423
# Shortening  for TN:  1209041_126-SchedMaint loop count424
# Shortening  for TN:  1209041_126-EMA loop count425
# Shortening  for TN:  1209041_126-UMA loop count426
# Shortening  for TN:  1209041_126-UnschedMaint loop count427
# Shortening  for TN:  1209041_126-MA loop count428
# Shortening  for TN:  1209041_126-MAF loop count429
# Shortening  for TN:  1209042_122-SchedMaint loop count430
# Shortening  for TN:  1209042_122-EMA loop count431
# Shortening  for TN:  1209042_122-UMA loop count432
# Shortening  for TN:  1209042_122-UnschedMaint loop count433
# Shortening  for TN:  1209042_122-MA loop count434
# Shortening  for TN:  1209042_122-MAF loop count435
# Shortening  for TN:  1209043_234-SchedMaint loop count436
# Shortening  for TN:  1209043_234-EMA loop count437
# Shortening  for TN:  1209043_234-UMA loop count438
# Shortening  for TN:  1209043_234-UnschedMaint loop count439
# Shortening  for TN:  1209043_234-MA loop count440
# Shortening  for TN:  1209043_234-MAF loop count441
# Shortening  for TN:  1303001_110-SchedMaint loop count442
# Shortening  for TN:  1303001_110-UMA loop count443
# Shortening  for TN:  1303001_110-UnschedMaint loop count444
# Shortening  for TN:  1303001_110-EMA loop count445
# Shortening  for TN:  1303001_110-MA loop count446
# Shortening  for TN:  1303001_110-MAF loop count447
# Shortening  for TN:  1303002_127-SchedMaint loop count448
# Shortening  for TN:  1303002_127-UMA loop count449
# Shortening  for TN:  1303002_127-UnschedMaint loop count450
# Shortening  for TN:  1303002_127-EMA loop count451
# Shortening  for TN:  1303002_127-MAF loop count452
# Shortening  for TN:  1303002_127-MA loop count453
# Shortening  for TN:  1303004_139-SchedMaint loop count454
# Shortening  for TN:  1303004_139-UMA loop count455
# Shortening  for TN:  1303004_139-UnschedMaint loop count456
# Shortening  for TN:  1303004_139-EMA loop count457
# Shortening  for TN:  1303004_139-MAF loop count458
# Shortening  for TN:  1303004_139-MA loop count459
# Shortening  for TN:  1303007_55-EMA loop count460
# Shortening  for TN:  1303007_54-SchedMaint loop count461
# Shortening  for TN:  1303007_55-SchedMaint loop count462
# Shortening  for TN:  1303007_55-UMA loop count463
# Shortening  for TN:  1303007_55-UnschedMaint loop count464
# Shortening  for TN:  1303007_54-UMA loop count465
# Shortening  for TN:  1303007_54-UnschedMaint loop count466
# Shortening  for TN:  1303007_54-EMA loop count467
# Shortening  for TN:  1303007_54-MAF loop count468
# Shortening  for TN:  1303007_55-MA loop count469
# Shortening  for TN:  1303007_55-MAF loop count470
# Shortening  for TN:  1303007_54-MA loop count471
# Shortening  for TN:  1303008_178-SchedMaint loop count472
# Shortening  for TN:  1303008_178-UMA loop count473
# Shortening  for TN:  1303008_178-UnschedMaint loop count474
# Shortening  for TN:  1303008_178-EMA loop count475
# Shortening  for TN:  1303008_178-MA loop count476
# Shortening  for TN:  1303008_178-MAF loop count477
# Shortening  for TN:  1401003_124-SchedMaint loop count478
# Shortening  for TN:  1401003_124-UMA loop count479
# Shortening  for TN:  1401003_124-UnschedMaint loop count480
# Shortening  for TN:  1401003_124-EMA loop count481
# Shortening  for TN:  1401003_124-MA loop count482
# Shortening  for TN:  1401003_124-MAF loop count483
# Shortening  for TN:  1401004_185-EMA loop count484
# Shortening  for TN:  1401004_185-SchedMaint loop count485
# Shortening  for TN:  1401004_185-UMA loop count486
# Shortening  for TN:  1401004_185-UnschedMaint loop count487
# Shortening  for TN:  1401004_185-MA loop count488
# Shortening  for TN:  1401004_185-MAF loop count489
# Shortening  for TN:  1401005_113-SchedMaint loop count490
# Shortening  for TN:  1401005_113-UMA loop count491
# Shortening  for TN:  1401005_113-UnschedMaint loop count492
# Shortening  for TN:  1401005_113-EMA loop count493
# Shortening  for TN:  1401005_113-MA loop count494
# Shortening  for TN:  1401005_113-MAF loop count495
# Shortening  for TN:  1401006_166-SchedMaint loop count496
# Shortening  for TN:  1401006_166-UMA loop count497
# Shortening  for TN:  1401006_166-UnschedMaint loop count498
# Shortening  for TN:  1401006_166-EMA loop count499
# Shortening  for TN:  1401006_166-MA loop count500
# Shortening  for TN:  1401006_166-MAF loop count501
# Shortening  for TN:  1401011_56-SchedMaint loop count502
# Shortening  for TN:  1401011_57-SchedMaint loop count503
# Shortening  for TN:  1401011_56-UMA loop count504
# Shortening  for TN:  1401011_56-UnschedMaint loop count505
# Shortening  for TN:  1401011_57-EMA loop count506
# Shortening  for TN:  1401011_57-UMA loop count507
# Shortening  for TN:  1401011_57-UnschedMaint loop count508
# Shortening  for TN:  1401011_56-EMA loop count509
# Shortening  for TN:  1401011_57-MAF loop count510
# Shortening  for TN:  1401011_56-MA loop count511
# Shortening  for TN:  1401011_56-MAF loop count512
# Shortening  for TN:  1401011_57-MA loop count513
# Shortening  for TN:  1401014_137-EMA loop count514
# Shortening  for TN:  1401014_137-MAF loop count515
# Shortening  for TN:  1401014_137-SchedMaint loop count516
# Shortening  for TN:  1401014_137-UMA loop count517
# Shortening  for TN:  1401014_137-UnschedMaint loop count518
# Shortening  for TN:  1401014_137-MA loop count519
# Shortening  for TN:  1401015_249-EMA loop count520
# Shortening  for TN:  1401015_249-MAF loop count521
# Shortening  for TN:  1401015_249-SchedMaint loop count522
# Shortening  for TN:  1401015_249-UMA loop count523
# Shortening  for TN:  1401015_249-UnschedMaint loop count524
# Shortening  for TN:  1401015_249-MA loop count525
# Shortening  for TN:  1401016_138-EMA loop count526
# Shortening  for TN:  1401016_138-SchedMaint loop count527
# Shortening  for TN:  1401016_138-UMA loop count528
# Shortening  for TN:  1401016_138-UnschedMaint loop count529
# Shortening  for TN:  1401016_138-MA loop count530
# Shortening  for TN:  1401016_138-MAF loop count531
# Shortening  for TN:  1401017_213-EMA loop count532
# Shortening  for TN:  1401017_213-SchedMaint loop count533
# Shortening  for TN:  1401017_213-UMA loop count534
# Shortening  for TN:  1401017_213-UnschedMaint loop count535
# Shortening  for TN:  1401017_213-MAF loop count536
# Shortening  for TN:  1401017_213-MA loop count537
# Shortening  for TN:  1403009_106-SchedMaint loop count538
# Shortening  for TN:  1403009_106-UMA loop count539
# Shortening  for TN:  1403009_106-UnschedMaint loop count540
# Shortening  for TN:  1403009_106-EMA loop count541
# Shortening  for TN:  1403009_106-MAF loop count542
# Shortening  for TN:  1403009_106-MA loop count543
# Shortening  for TN:  1403010_108-EMA loop count544
# Shortening  for TN:  1403010_108-SchedMaint loop count545
# Shortening  for TN:  1403010_108-UMA loop count546
# Shortening  for TN:  1403010_108-UnschedMaint loop count547
# Shortening  for TN:  1403010_108-MA loop count548
# Shortening  for TN:  1403010_108-MAF loop count549
# Shortening  for TN:  1403011_118-SchedMaint loop count550
# Shortening  for TN:  1403011_118-UMA loop count551
# Shortening  for TN:  1403011_118-UnschedMaint loop count552
# Shortening  for TN:  1403011_118-EMA loop count553
# Shortening  for TN:  1403011_118-MA loop count554
# Shortening  for TN:  1403011_118-MAF loop count555
# Shortening  for TN:  1403012_223-SchedMaint loop count556
# Shortening  for TN:  1403012_223-UMA loop count557
# Shortening  for TN:  1403012_223-UnschedMaint loop count558
# Shortening  for TN:  1403012_223-EMA loop count559
# Shortening  for TN:  1403012_223-MA loop count560
# Shortening  for TN:  1403012_223-MAF loop count561
# Shortening  for TN:  1403013_168-SchedMaint loop count562
# Shortening  for TN:  1403013_168-UMA loop count563
# Shortening  for TN:  1403013_168-UnschedMaint loop count564
# Shortening  for TN:  1403013_168-EMA loop count565
# Shortening  for TN:  1403013_168-MAF loop count566
# Shortening  for TN:  1403013_168-MA loop count567
# Shortening  for TN:  1403021_128-SchedMaint loop count568
# Shortening  for TN:  1403021_128-UMA loop count569
# Shortening  for TN:  1403021_128-UnschedMaint loop count570
# Shortening  for TN:  1403021_128-EMA loop count571
# Shortening  for TN:  1403021_128-MAF loop count572
# Shortening  for TN:  1403021_128-MA loop count573
# Shortening  for TN:  1403022_229-EMA loop count574
# Shortening  for TN:  1403022_229-SchedMaint loop count575
# Shortening  for TN:  1403022_229-UMA loop count576
# Shortening  for TN:  1403022_229-UnschedMaint loop count577
# Shortening  for TN:  1403022_229-MA loop count578
# Shortening  for TN:  1403022_229-MAF loop count579
# Shortening  for TN:  1403023_242-SchedMaint loop count580
# Shortening  for TN:  1403023_242-UMA loop count581
# Shortening  for TN:  1403023_242-UnschedMaint loop count582
# Shortening  for TN:  1403023_242-EMA loop count583
# Shortening  for TN:  1403023_242-MAF loop count584
# Shortening  for TN:  1403023_242-MA loop count585
# Shortening  for TN:  1403024_189-EMA loop count586
# Shortening  for TN:  1403024_189-SchedMaint loop count587
# Shortening  for TN:  1403024_189-UMA loop count588
# Shortening  for TN:  1403024_189-UnschedMaint loop count589
# Shortening  for TN:  1403024_189-MAF loop count590
# Shortening  for TN:  1403024_189-MA loop count591
# Shortening  for TN:  1403025_162-EMA loop count592
# Shortening  for TN:  1403025_162-SchedMaint loop count593
# Shortening  for TN:  1403025_162-UMA loop count594
# Shortening  for TN:  1403025_162-UnschedMaint loop count595
# Shortening  for TN:  1403025_162-MAF loop count596
# Shortening  for TN:  1403025_162-MA loop count597
# Shortening  for TN:  1403026_172-SchedMaint loop count598
# Shortening  for TN:  1403026_172-UMA loop count599
# Shortening  for TN:  1403026_172-UnschedMaint loop count600
# Shortening  for TN:  1403026_172-EMA loop count601
# Shortening  for TN:  1403026_172-MA loop count602
# Shortening  for TN:  1403026_172-MAF loop count603
# Shortening  for TN:  1403027_159-SchedMaint loop count604
# Shortening  for TN:  1403027_159-UMA loop count605
# Shortening  for TN:  1403027_159-UnschedMaint loop count606
# Shortening  for TN:  1403027_159-EMA loop count607
# Shortening  for TN:  1403027_159-MAF loop count608
# Shortening  for TN:  1403027_159-MA loop count609
# Shortening  for TN:  1403028_203-EMA loop count610
# Shortening  for TN:  1403028_203-MAF loop count611
# Shortening  for TN:  1403028_203-SchedMaint loop count612
# Shortening  for TN:  1403028_203-UMA loop count613
# Shortening  for TN:  1403028_203-UnschedMaint loop count614
# Shortening  for TN:  1403028_203-MA loop count615
# Shortening  for TN:  1403029_132-SchedMaint loop count616
# Shortening  for TN:  1403029_132-UMA loop count617
# Shortening  for TN:  1403029_132-UnschedMaint loop count618
# Shortening  for TN:  1403029_132-EMA loop count619
# Shortening  for TN:  1403029_132-MA loop count620
# Shortening  for TN:  1403029_132-MAF loop count621
# Shortening  for TN:  1403030_150-EMA loop count622
# Shortening  for TN:  1403030_150-SchedMaint loop count623
# Shortening  for TN:  1403030_150-UMA loop count624
# Shortening  for TN:  1403030_150-UnschedMaint loop count625
# Shortening  for TN:  1403030_150-MA loop count626
# Shortening  for TN:  1403030_150-MAF loop count627
# Shortening  for TN:  1403031_227-SchedMaint loop count628
# Shortening  for TN:  1403031_227-UMA loop count629
# Shortening  for TN:  1403031_227-UnschedMaint loop count630
# Shortening  for TN:  1403031_227-EMA loop count631
# Shortening  for TN:  1403031_227-MA loop count632
# Shortening  for TN:  1403031_227-MAF loop count633
# Shortening  for TN:  1403032_59-EMA loop count634
# Shortening  for TN:  1403032_59-MA loop count635
# Shortening  for TN:  1403032_59-MAF loop count636
# Shortening  for TN:  1403032_58-SchedMaint loop count637
# Shortening  for TN:  1403032_59-SchedMaint loop count638
# Shortening  for TN:  1403032_58-UMA loop count639
# Shortening  for TN:  1403032_59-UMA loop count640
# Shortening  for TN:  1403032_58-UnschedMaint loop count641
# Shortening  for TN:  1403032_59-UnschedMaint loop count642
# Shortening  for TN:  1403032_58-EMA loop count643
# Shortening  for TN:  1403032_58-MA loop count644
# Shortening  for TN:  1403032_58-MAF loop count645
# Shortening  for TN:  1403033_61-EMA loop count646
# Shortening  for TN:  1403033_60-SchedMaint loop count647
# Shortening  for TN:  1403033_61-SchedMaint loop count648
# Shortening  for TN:  1403033_60-UMA loop count649
# Shortening  for TN:  1403033_61-UMA loop count650
# Shortening  for TN:  1403033_60-UnschedMaint loop count651
# Shortening  for TN:  1403033_61-UnschedMaint loop count652
# Shortening  for TN:  1403033_60-EMA loop count653
# Shortening  for TN:  1403033_61-MA loop count654
# Shortening  for TN:  1403033_61-MAF loop count655
# Shortening  for TN:  1403033_60-MA loop count656
# Shortening  for TN:  1403033_60-MAF loop count657
# Shortening  for TN:  1403034_63-EMA loop count658
# Shortening  for TN:  1403034_62-SchedMaint loop count659
# Shortening  for TN:  1403034_63-SchedMaint loop count660
# Shortening  for TN:  1403034_62-UMA loop count661
# Shortening  for TN:  1403034_63-UMA loop count662
# Shortening  for TN:  1403034_62-UnschedMaint loop count663
# Shortening  for TN:  1403034_63-UnschedMaint loop count664
# Shortening  for TN:  1403034_62-EMA loop count665
# Shortening  for TN:  1403034_62-MA loop count666
# Shortening  for TN:  1403034_62-MAF loop count667
# Shortening  for TN:  1403034_63-MA loop count668
# Shortening  for TN:  1403034_63-MAF loop count669
# Shortening  for TN:  1403035_64-SchedMaint loop count670
# Shortening  for TN:  1403035_65-SchedMaint loop count671
# Shortening  for TN:  1403035_64-UMA loop count672
# Shortening  for TN:  1403035_65-UMA loop count673
# Shortening  for TN:  1403035_64-UnschedMaint loop count674
# Shortening  for TN:  1403035_65-UnschedMaint loop count675
# Shortening  for TN:  1403035_65-EMA loop count676
# Shortening  for TN:  1403035_64-EMA loop count677
# Shortening  for TN:  1403035_64-MA loop count678
# Shortening  for TN:  1403035_64-MAF loop count679
# Shortening  for TN:  1403035_65-MA loop count680
# Shortening  for TN:  1403035_65-MAF loop count681
# Shortening  for TN:  1403036_67-EMA loop count682
# Shortening  for TN:  1403036_66-SchedMaint loop count683
# Shortening  for TN:  1403036_67-SchedMaint loop count684
# Shortening  for TN:  1403036_66-UMA loop count685
# Shortening  for TN:  1403036_67-UMA loop count686
# Shortening  for TN:  1403036_66-UnschedMaint loop count687
# Shortening  for TN:  1403036_67-UnschedMaint loop count688
# Shortening  for TN:  1403036_66-EMA loop count689
# Shortening  for TN:  1403036_66-MA loop count690
# Shortening  for TN:  1403036_66-MAF loop count691
# Shortening  for TN:  1403036_67-MAF loop count692
# Shortening  for TN:  1403036_67-MA loop count693
# Shortening  for TN:  1403037_68-SchedMaint loop count694
# Shortening  for TN:  1403037_69-SchedMaint loop count695
# Shortening  for TN:  1403037_68-UMA loop count696
# Shortening  for TN:  1403037_69-UMA loop count697
# Shortening  for TN:  1403037_68-UnschedMaint loop count698
# Shortening  for TN:  1403037_69-UnschedMaint loop count699
# Shortening  for TN:  1403037_69-EMA loop count700
# Shortening  for TN:  1403037_68-EMA loop count701
# Shortening  for TN:  1403037_69-MA loop count702
# Shortening  for TN:  1403037_69-MAF loop count703
# Shortening  for TN:  1403037_68-MAF loop count704
# Shortening  for TN:  1403037_68-MA loop count705
# Shortening  for TN:  1403038_70-SchedMaint loop count706
# Shortening  for TN:  1403038_71-SchedMaint loop count707
# Shortening  for TN:  1403038_70-UMA loop count708
# Shortening  for TN:  1403038_71-UMA loop count709
# Shortening  for TN:  1403038_70-UnschedMaint loop count710
# Shortening  for TN:  1403038_71-UnschedMaint loop count711
# Shortening  for TN:  1403038_71-EMA loop count712
# Shortening  for TN:  1403038_70-EMA loop count713
# Shortening  for TN:  1403038_71-MA loop count714
# Shortening  for TN:  1403038_71-MAF loop count715
# Shortening  for TN:  1403038_70-MAF loop count716
# Shortening  for TN:  1403038_70-MA loop count717
# Shortening  for TN:  1403039_73-EMA loop count718
# Shortening  for TN:  1403039_72-SchedMaint loop count719
# Shortening  for TN:  1403039_73-SchedMaint loop count720
# Shortening  for TN:  1403039_72-UMA loop count721
# Shortening  for TN:  1403039_73-UMA loop count722
# Shortening  for TN:  1403039_72-UnschedMaint loop count723
# Shortening  for TN:  1403039_73-UnschedMaint loop count724
# Shortening  for TN:  1403039_72-EMA loop count725
# Shortening  for TN:  1403039_73-MA loop count726
# Shortening  for TN:  1403039_73-MAF loop count727
# Shortening  for TN:  1403039_72-MA loop count728
# Shortening  for TN:  1403039_72-MAF loop count729
# Shortening  for TN:  1503046_228-SchedMaint loop count730
# Shortening  for TN:  1503046_228-UMA loop count731
# Shortening  for TN:  1503046_228-UnschedMaint loop count732
# Shortening  for TN:  1503046_228-EMA loop count733
# Shortening  for TN:  1503046_228-MA loop count734
# Shortening  for TN:  1503046_228-MAF loop count735
# Shortening  for TN:  1603081_201-SchedMaint loop count736
# Shortening  for TN:  1603081_201-UMA loop count737
# Shortening  for TN:  1603081_201-UnschedMaint loop count738
# Shortening  for TN:  1603081_201-EMA loop count739
# Shortening  for TN:  1603081_201-MAF loop count740
# Shortening  for TN:  1603081_201-MA loop count741
# Shortening  for TN:  1603082_238-EMA loop count742
# Shortening  for TN:  1603082_238-SchedMaint loop count743
# Shortening  for TN:  1603082_238-UMA loop count744
# Shortening  for TN:  1603082_238-UnschedMaint loop count745
# Shortening  for TN:  1603082_238-MAF loop count746
# Shortening  for TN:  1603082_238-MA loop count747
# Shortening  for TN:  1603083_75-EMA loop count748
# Shortening  for TN:  1603083_74-SchedMaint loop count749
# Shortening  for TN:  1603083_75-SchedMaint loop count750
# Shortening  for TN:  1603083_74-UMA loop count751
# Shortening  for TN:  1603083_75-UMA loop count752
# Shortening  for TN:  1603083_74-UnschedMaint loop count753
# Shortening  for TN:  1603083_75-UnschedMaint loop count754
# Shortening  for TN:  1603083_74-EMA loop count755
# Shortening  for TN:  1603083_75-MA loop count756
# Shortening  for TN:  1603083_75-MAF loop count757
# Shortening  for TN:  1603083_74-MA loop count758
# Shortening  for TN:  1603083_74-MAF loop count759
# Shortening  for TN:  1603084_76-SchedMaint loop count760
# Shortening  for TN:  1603084_77-SchedMaint loop count761
# Shortening  for TN:  1603084_76-UMA loop count762
# Shortening  for TN:  1603084_77-UMA loop count763
# Shortening  for TN:  1603084_76-UnschedMaint loop count764
# Shortening  for TN:  1603084_77-UnschedMaint loop count765
# Shortening  for TN:  1603084_77-EMA loop count766
# Shortening  for TN:  1603084_76-EMA loop count767
# Shortening  for TN:  1603084_77-MA loop count768
# Shortening  for TN:  1603084_77-MAF loop count769
# Shortening  for TN:  1603084_76-MA loop count770
# Shortening  for TN:  1603084_76-MAF loop count771
# Shortening  for TN:  1603085_78-EMA loop count772
# Shortening  for TN:  1603085_79-EMA loop count773
# Shortening  for TN:  1603085_78-MA loop count774
# Shortening  for TN:  1603085_78-MAF loop count775
# Shortening  for TN:  1603085_78-SchedMaint loop count776
# Shortening  for TN:  1603085_79-SchedMaint loop count777
# Shortening  for TN:  1603085_78-UMA loop count778
# Shortening  for TN:  1603085_79-UMA loop count779
# Shortening  for TN:  1603085_78-UnschedMaint loop count780
# Shortening  for TN:  1603085_79-UnschedMaint loop count781
# Shortening  for TN:  1603085_79-MAF loop count782
# Shortening  for TN:  1603085_79-MA loop count783
# Shortening  for TN:  1603086_81-EMA loop count784
# Shortening  for TN:  1603086_80-SchedMaint loop count785
# Shortening  for TN:  1603086_81-SchedMaint loop count786
# Shortening  for TN:  1603086_80-UMA loop count787
# Shortening  for TN:  1603086_81-UMA loop count788
# Shortening  for TN:  1603086_80-UnschedMaint loop count789
# Shortening  for TN:  1603086_81-UnschedMaint loop count790
# Shortening  for TN:  1603086_80-EMA loop count791
# Shortening  for TN:  1603086_81-MA loop count792
# Shortening  for TN:  1603086_81-MAF loop count793
# Shortening  for TN:  1603086_80-MA loop count794
# Shortening  for TN:  1603086_80-MAF loop count795
# Shortening  for TN:  1603087_83-EMA loop count796
# Shortening  for TN:  1603087_82-SchedMaint loop count797
# Shortening  for TN:  1603087_83-SchedMaint loop count798
# Shortening  for TN:  1603087_82-UMA loop count799
# Shortening  for TN:  1603087_83-UMA loop count800
# Shortening  for TN:  1603087_82-UnschedMaint loop count801
# Shortening  for TN:  1603087_83-UnschedMaint loop count802
# Shortening  for TN:  1603087_83-MA loop count803
# Shortening  for TN:  1603087_83-MAF loop count804
# Shortening  for TN:  1603087_82-EMA loop count805
# Shortening  for TN:  1603087_82-MA loop count806
# Shortening  for TN:  1603087_82-MAF loop count807
# Shortening  for TN:  1603088_85-EMA loop count808
# Shortening  for TN:  1603088_84-SchedMaint loop count809
# Shortening  for TN:  1603088_85-SchedMaint loop count810
# Shortening  for TN:  1603088_84-UMA loop count811
# Shortening  for TN:  1603088_85-UMA loop count812
# Shortening  for TN:  1603088_84-UnschedMaint loop count813
# Shortening  for TN:  1603088_85-UnschedMaint loop count814
# Shortening  for TN:  1603088_84-EMA loop count815
# Shortening  for TN:  1603088_85-MAF loop count816
# Shortening  for TN:  1603088_85-MA loop count817
# Shortening  for TN:  1603088_84-MAF loop count818
# Shortening  for TN:  1603088_84-MA loop count819
# Shortening  for TN:  1603089_211-SchedMaint loop count820
# Shortening  for TN:  1603089_211-UMA loop count821
# Shortening  for TN:  1603089_211-UnschedMaint loop count822
# Shortening  for TN:  1603089_211-EMA loop count823
# Shortening  for TN:  1603089_211-MAF loop count824
# Shortening  for TN:  1603089_211-MA loop count825
# Shortening  for TN:  1603090_87-EMA loop count826
# Shortening  for TN:  1603090_86-SchedMaint loop count827
# Shortening  for TN:  1603090_87-SchedMaint loop count828
# Shortening  for TN:  1603090_86-UMA loop count829
# Shortening  for TN:  1603090_87-UMA loop count830
# Shortening  for TN:  1603090_86-UnschedMaint loop count831
# Shortening  for TN:  1603090_87-UnschedMaint loop count832
# Shortening  for TN:  1603090_87-MA loop count833
# Shortening  for TN:  1603090_87-MAF loop count834
# Shortening  for TN:  1603090_86-EMA loop count835
# Shortening  for TN:  1603090_86-MA loop count836
# Shortening  for TN:  1603090_86-MAF loop count837
# Shortening  for TN:  1603091_88-EMA loop count838
# Shortening  for TN:  1603091_89-EMA loop count839
# Shortening  for TN:  1603091_89-MAF loop count840
# Shortening  for TN:  1603091_88-SchedMaint loop count841
# Shortening  for TN:  1603091_89-SchedMaint loop count842
# Shortening  for TN:  1603091_88-UMA loop count843
# Shortening  for TN:  1603091_89-UMA loop count844
# Shortening  for TN:  1603091_88-UnschedMaint loop count845
# Shortening  for TN:  1603091_89-UnschedMaint loop count846
# Shortening  for TN:  1603091_88-MAF loop count847
# Shortening  for TN:  1603091_88-MA loop count848
# Shortening  for TN:  1603091_89-MA loop count849
# Shortening  for TN:  1603092_246-EMA loop count850
# Shortening  for TN:  1603092_246-SchedMaint loop count851
# Shortening  for TN:  1603092_246-UMA loop count852
# Shortening  for TN:  1603092_246-UnschedMaint loop count853
# Shortening  for TN:  1603092_246-MA loop count854
# Shortening  for TN:  1603092_246-MAF loop count855
# Shortening  for TN:  1603093_133-EMA loop count856
# Shortening  for TN:  1603093_133-MA loop count857
# Shortening  for TN:  1603093_133-MAF loop count858
# Shortening  for TN:  1603093_133-SchedMaint loop count859
# Shortening  for TN:  1603093_133-UMA loop count860
# Shortening  for TN:  1603093_133-UnschedMaint loop count861
# Shortening  for TN:  1603094_181-EMA loop count862
# Shortening  for TN:  1603094_181-SchedMaint loop count863
# Shortening  for TN:  1603094_181-UMA loop count864
# Shortening  for TN:  1603094_181-UnschedMaint loop count865
# Shortening  for TN:  1603094_181-MAF loop count866
# Shortening  for TN:  1603094_181-MA loop count867
# Shortening  for TN:  1603095_245-EMA loop count868
# Shortening  for TN:  1603095_245-SchedMaint loop count869
# Shortening  for TN:  1603095_245-UMA loop count870
# Shortening  for TN:  1603095_245-UnschedMaint loop count871
# Shortening  for TN:  1603095_245-MAF loop count872
# Shortening  for TN:  1603095_245-MA loop count873
# Shortening  for TN:  1603096_250-SchedMaint loop count874
# Shortening  for TN:  1603096_250-UMA loop count875
# Shortening  for TN:  1603096_250-UnschedMaint loop count876
# Shortening  for TN:  1603096_250-EMA loop count877
# Shortening  for TN:  1603096_250-MAF loop count878
# Shortening  for TN:  1603096_250-MA loop count879
# Shortening  for TN:  1603097_176-EMA loop count880
# Shortening  for TN:  1603097_176-SchedMaint loop count881
# Shortening  for TN:  1603097_176-UMA loop count882
# Shortening  for TN:  1603097_176-UnschedMaint loop count883
# Shortening  for TN:  1603097_176-MA loop count884
# Shortening  for TN:  1603097_176-MAF loop count885
# Shortening  for TN:  1603098_90-EMA loop count886
# Shortening  for TN:  1603098_91-EMA loop count887
# Shortening  for TN:  1603098_90-SchedMaint loop count888
# Shortening  for TN:  1603098_91-SchedMaint loop count889
# Shortening  for TN:  1603098_90-UMA loop count890
# Shortening  for TN:  1603098_91-UMA loop count891
# Shortening  for TN:  1603098_90-UnschedMaint loop count892
# Shortening  for TN:  1603098_91-UnschedMaint loop count893
# Shortening  for TN:  1603098_90-MA loop count894
# Shortening  for TN:  1603098_90-MAF loop count895
# Shortening  for TN:  1603098_91-MA loop count896
# Shortening  for TN:  1603098_91-MAF loop count897
# Shortening  for TN:  1603099_93-EMA loop count898
# Shortening  for TN:  1603099_93-MA loop count899
# Shortening  for TN:  1603099_93-MAF loop count900
# Shortening  for TN:  1603099_92-SchedMaint loop count901
# Shortening  for TN:  1603099_93-SchedMaint loop count902
# Shortening  for TN:  1603099_93-UMA loop count903
# Shortening  for TN:  1603099_93-UnschedMaint loop count904
# Shortening  for TN:  1603099_92-UMA loop count905
# Shortening  for TN:  1603099_92-UnschedMaint loop count906
# Shortening  for TN:  1603099_92-EMA loop count907
# Shortening  for TN:  1603100_192-EMA loop count908
# Shortening  for TN:  1603100_192-SchedMaint loop count909
# ...
# Shortening  for TN:  1703160_114-UMA loop count1198
# Shortening  for TN:  1703160_114-UnschedMaint loop count1199
# Shortening  for TN:  1703160_114-MA loop count1200
# Shortening  for TN:  1703160_114-MAF loop count1201
# Shortening  for TN:  1703163_154-EMA loop count1202
# Shortening  for TN:  1703163_154-SchedMaint loop count1203
# Shortening  for TN:  1703163_154-UMA loop count1204
# Shortening  for TN:  1703163_154-UnschedMaint loop count1205
# Shortening  for TN:  1703163_154-MA loop count1206
# Shortening  for TN:  1703163_154-MAF loop count1207
# Shortening  for TN:  1703164_119-EMA loop count1208
# Shortening  for TN:  1703164_119-SchedMaint loop count1209
# Shortening  for TN:  1703164_119-UMA loop count1210
# Shortening  for TN:  1703164_119-UnschedMaint loop count1211
# Shortening  for TN:  1703164_119-MA loop count1212
# Shortening  for TN:  1703164_119-MAF loop count1213
# Shortening  for TN:  1703165_221-EMA loop count1214
# Shortening  for TN:  1703165_221-SchedMaint loop count1215
# Shortening  for TN:  1703165_221-UMA loop count1216
# Shortening  for TN:  1703165_221-UnschedMaint loop count1217
# Shortening  for TN:  1703165_221-MA loop count1218
# Shortening  for TN:  1703165_221-MAF loop count1219
# Shortening  for TN:  1703166_236-EMA loop count1220
# Shortening  for TN:  1703166_236-SchedMaint loop count1221
# Shortening  for TN:  1703166_236-UMA loop count1222
# Shortening  for TN:  1703166_236-UnschedMaint loop count1223
# Shortening  for TN:  1703166_236-MAF loop count1224
# Shortening  for TN:  1703166_236-MA loop count1225
# Shortening  for TN:  1703168_174-EMA loop count1226
# Shortening  for TN:  1703168_174-SchedMaint loop count1227
# Shortening  for TN:  1703168_174-UMA loop count1228
# Shortening  for TN:  1703168_174-UnschedMaint loop count1229
# Shortening  for TN:  1703168_174-MA loop count1230
# Shortening  for TN:  1703168_174-MAF loop count1231
# Shortening  for TN:  1703169_244-EMA loop count1232
# Shortening  for TN:  1703169_244-SchedMaint loop count1233
# Shortening  for TN:  1703169_244-UMA loop count1234
# Shortening  for TN:  1703169_244-UnschedMaint loop count1235
# Shortening  for TN:  1703169_244-MAF loop count1236
# Shortening  for TN:  1703169_244-MA loop count1237
# Shortening  for TN:  1703170_155-SchedMaint loop count1238
# Shortening  for TN:  1703170_155-UMA loop count1239
# Shortening  for TN:  1703170_155-UnschedMaint loop count1240
# Shortening  for TN:  1703170_155-EMA loop count1241
# Shortening  for TN:  1703170_155-MA loop count1242
# Shortening  for TN:  1703170_155-MAF loop count1243
# Shortening  for TN:  1703171_247-EMA loop count1244
# Shortening  for TN:  1703171_247-SchedMaint loop count1245
# Shortening  for TN:  1703171_247-UMA loop count1246
# Shortening  for TN:  1703171_247-UnschedMaint loop count1247
# Shortening  for TN:  1703171_247-MA loop count1248
# Shortening  for TN:  1703171_247-MAF loop count1249
# Shortening  for TN:  1703173_195-EMA loop count1250
# Shortening  for TN:  1703173_195-SchedMaint loop count1251
# Shortening  for TN:  1703173_195-UMA loop count1252
# Shortening  for TN:  1703173_195-UnschedMaint loop count1253
# Shortening  for TN:  1703173_195-MA loop count1254
# Shortening  for TN:  1703173_195-MAF loop count1255
# Shortening  for TN:  1703174_194-SchedMaint loop count1256
# Shortening  for TN:  1703174_194-UMA loop count1257
# Shortening  for TN:  1703174_194-UnschedMaint loop count1258
# Shortening  for TN:  1703174_194-EMA loop count1259
# Shortening  for TN:  1703174_194-MAF loop count1260
# Shortening  for TN:  1703174_194-MA loop count1261
# Shortening  for TN:  1703175_180-SchedMaint loop count1262
# Shortening  for TN:  1703175_180-UMA loop count1263
# Shortening  for TN:  1703175_180-UnschedMaint loop count1264
# Shortening  for TN:  1703175_180-EMA loop count1265
# Shortening  for TN:  1703175_180-MA loop count1266
# Shortening  for TN:  1703175_180-MAF loop count1267
# Shortening  for TN:  1803209_191-EMA loop count1268
# Shortening  for TN:  1803209_191-SchedMaint loop count1269
# Shortening  for TN:  1803209_191-UMA loop count1270
# Shortening  for TN:  1803209_191-UnschedMaint loop count1271
# Shortening  for TN:  1803209_191-MA loop count1272
# Shortening  for TN:  1803209_191-MAF loop count1273
# Shortening  for TN:  1803210_232-EMA loop count1274
# Shortening  for TN:  1803210_232-MA loop count1275
# Shortening  for TN:  1803210_232-MAF loop count1276
# Shortening  for TN:  1803210_232-SchedMaint loop count1277
# Shortening  for TN:  1803210_232-UMA loop count1278
# Shortening  for TN:  1803210_232-UnschedMaint loop count1279
# Shortening  for TN:  1803211_225-EMA loop count1280
# Shortening  for TN:  1803211_225-SchedMaint loop count1281
# Shortening  for TN:  1803211_225-UMA loop count1282
# Shortening  for TN:  1803211_225-UnschedMaint loop count1283
# Shortening  for TN:  1803211_225-MA loop count1284
# Shortening  for TN:  1803211_225-MAF loop count1285
# Shortening  for TN:  1803212_240-EMA loop count1286
# Shortening  for TN:  1803212_240-SchedMaint loop count1287
# Shortening  for TN:  1803212_240-UMA loop count1288
# Shortening  for TN:  1803212_240-UnschedMaint loop count1289
# Shortening  for TN:  1803212_240-MA loop count1290
# Shortening  for TN:  1803212_240-MAF loop count1291
# Shortening  for TN:  1803213_151-EMA loop count1292
# Shortening  for TN:  1803213_151-SchedMaint loop count1293
# Shortening  for TN:  1803213_151-UMA loop count1294
# Shortening  for TN:  1803213_151-UnschedMaint loop count1295
# Shortening  for TN:  1803213_151-MA loop count1296
# Shortening  for TN:  1803213_151-MAF loop count1297
# Shortening  for TN:  1803214_237-EMA loop count1298
# Shortening  for TN:  1803214_237-SchedMaint loop count1299
# Shortening  for TN:  1803214_237-UMA loop count1300
# Shortening  for TN:  1803214_237-UnschedMaint loop count1301
# Shortening  for TN:  1803214_237-MA loop count1302
# Shortening  for TN:  1803214_237-MAF loop count1303
# Shortening  for TN:  1803215_206-SchedMaint loop count1304
# Shortening  for TN:  1803215_206-UMA loop count1305
# Shortening  for TN:  1803215_206-UnschedMaint loop count1306
# Shortening  for TN:  1803215_206-EMA loop count1307
# Shortening  for TN:  1803215_206-MA loop count1308
# Shortening  for TN:  1803215_206-MAF loop count1309
# Shortening  for TN:  1803216_209-EMA loop count1310
# Shortening  for TN:  1803216_209-SchedMaint loop count1311
# Shortening  for TN:  1803216_209-UMA loop count1312
# Shortening  for TN:  1803216_209-UnschedMaint loop count1313
# Shortening  for TN:  1803216_209-MAF loop count1314
# Shortening  for TN:  1803216_209-MA loop count1315
# Shortening  for TN:  1803217_220-EMA loop count1316
# Shortening  for TN:  1803217_220-SchedMaint loop count1317
# Shortening  for TN:  1803217_220-UMA loop count1318
# Shortening  for TN:  1803217_220-UnschedMaint loop count1319
# Shortening  for TN:  1803217_220-MAF loop count1320
# Shortening  for TN:  1803217_220-MA loop count1321
# Shortening  for TN:  1803218_130-SchedMaint loop count1322
# Shortening  for TN:  1803218_130-UMA loop count1323
# Shortening  for TN:  1803218_130-UnschedMaint loop count1324
# Shortening  for TN:  1803218_130-EMA loop count1325
# Shortening  for TN:  1803218_130-MAF loop count1326
# Shortening  for TN:  1803218_130-MA loop count1327
# Shortening  for TN:  1803219_197-SchedMaint loop count1328
# Shortening  for TN:  1803219_197-UMA loop count1329
# Shortening  for TN:  1803219_197-UnschedMaint loop count1330
# Shortening  for TN:  1803219_197-EMA loop count1331
# Shortening  for TN:  1803219_197-MA loop count1332
# Shortening  for TN:  1803219_197-MAF loop count1333
# Shortening  for TN:  1803220_204-SchedMaint loop count1334
# Shortening  for TN:  1803220_204-UMA loop count1335
# Shortening  for TN:  1803220_204-UnschedMaint loop count1336
# Shortening  for TN:  1803220_204-EMA loop count1337
# Shortening  for TN:  1803220_204-MA loop count1338
# Shortening  for TN:  1803220_204-MAF loop count1339
# Shortening  for TN:  1803221_214-EMA loop count1340
# Shortening  for TN:  1803221_214-SchedMaint loop count1341
# Shortening  for TN:  1803221_214-UMA loop count1342
# Shortening  for TN:  1803221_214-UnschedMaint loop count1343
# Shortening  for TN:  1803221_214-MAF loop count1344
# Shortening  for TN:  1803221_214-MA loop count1345
# Shortening  for TN:  1803222_231-EMA loop count1346
# Shortening  for TN:  1803222_231-SchedMaint loop count1347
# Shortening  for TN:  1803222_231-UMA loop count1348
# Shortening  for TN:  1803222_231-UnschedMaint loop count1349
# Shortening  for TN:  1803222_231-MA loop count1350
# Shortening  for TN:  1803222_231-MAF loop count1351
# Shortening  for TN:  1803224_226-SchedMaint loop count1352
# Shortening  for TN:  1803224_226-UMA loop count1353
# Shortening  for TN:  1803224_226-UnschedMaint loop count1354
# Shortening  for TN:  1803224_226-EMA loop count1355
# Shortening  for TN:  1803224_226-MA loop count1356
# Shortening  for TN:  1803224_226-MAF loop count1357
# Shortening  for TN:  1803225_233-SchedMaint loop count1358
# Shortening  for TN:  1803225_233-EMA loop count1359
# Shortening  for TN:  1803225_233-UMA loop count1360
# Shortening  for TN:  1803225_233-UnschedMaint loop count1361
# Shortening  for TN:  1803225_233-MA loop count1362
# Shortening  for TN:  1803225_233-MAF loop count1363
# Shortening  for TN:  1803226_215-SchedMaint loop count1364
# Shortening  for TN:  1803226_215-UMA loop count1365
# Shortening  for TN:  1803226_215-UnschedMaint loop count1366
# Shortening  for TN:  1803226_215-EMA loop count1367
# Shortening  for TN:  1803226_215-MA loop count1368
# Shortening  for TN:  1803226_215-MAF loop count1369
# Shortening  for TN:  1803229_170-SchedMaint loop count1370
# Shortening  for TN:  1803229_170-UMA loop count1371
# Shortening  for TN:  1803229_170-UnschedMaint loop count1372
# Shortening  for TN:  1803229_170-EMA loop count1373
# Shortening  for TN:  1803229_170-MAF loop count1374
# Shortening  for TN:  1803230_109-SchedMaint loop count1375
# Shortening  for TN:  1803230_109-EMA loop count1376
# Shortening  for TN:  1803230_109-UMA loop count1377
# Shortening  for TN:  1803230_109-UnschedMaint loop count1378
# Shortening  for TN:  1803231_224-SchedMaint loop count1379
# Shortening  for TN:  1803231_224-UMA loop count1380
# Shortening  for TN:  1803231_224-UnschedMaint loop count1381
# Shortening  for TN:  1803231_224-EMA loop count1382
# Shortening  for TN:  1803231_224-MA loop count1383
# Shortening  for TN:  1803231_224-MAF loop count1384
# Shortening  for TN:  1803235_121-EMA loop count1385
# Shortening  for TN:  1803235_121-SchedMaint loop count1386
# Shortening  for TN:  1803235_121-UMA loop count1387
# Shortening  for TN:  1803235_121-UnschedMaint loop count1388
# Shortening  for TN:  1803235_121-MA loop count1389
# Shortening  for TN:  1803235_121-MAF loop count1390
# Shortening  for TN:  1803236_171-EMA loop count1391
# Shortening  for TN:  1803236_171-SchedMaint loop count1392
# Shortening  for TN:  1803236_171-UMA loop count1393
# Shortening  for TN:  1803236_171-UnschedMaint loop count1394
# Shortening  for TN:  1803236_171-MA loop count1395
# Shortening  for TN:  1803236_171-MAF loop count1396
# Shortening  for TN:  1803237_156-EMA loop count1397
# Shortening  for TN:  1803237_156-SchedMaint loop count1398
# Shortening  for TN:  1803237_156-UMA loop count1399
# Shortening  for TN:  1803237_156-UnschedMaint loop count1400
# Shortening  for TN:  1803237_156-MAF loop count1401
# Shortening  for TN:  1803237_156-MA loop count1402
# Shortening  for TN:  1803238_123-EMA loop count1403
# Shortening  for TN:  1803238_123-SchedMaint loop count1404
# Shortening  for TN:  1803238_123-UMA loop count1405
# Shortening  for TN:  1803238_123-UnschedMaint loop count1406
# Shortening  for TN:  1803238_123-MAF loop count1407
# Shortening  for TN:  1803238_123-MA loop count1408
# Shortening  for TN:  1803239_202-EMA loop count1409
# Shortening  for TN:  1803239_202-SchedMaint loop count1410
# Shortening  for TN:  1803239_202-UMA loop count1411
# Shortening  for TN:  1803239_202-UnschedMaint loop count1412
# Shortening  for TN:  1803239_202-MAF loop count1413
# Shortening  for TN:  1803239_202-MA loop count1414
# Shortening  for TN:  1803240_148-EMA loop count1415
# Shortening  for TN:  1803240_148-SchedMaint loop count1416
# Shortening  for TN:  1803240_148-UMA loop count1417
# Shortening  for TN:  1803240_148-UnschedMaint loop count1418
# Shortening  for TN:  1803240_148-MAF loop count1419
# Shortening  for TN:  1803240_148-MA loop count1420
# Shortening  for TN:  1803241_145-EMA loop count1421
# Shortening  for TN:  1803241_145-SchedMaint loop count1422
# Shortening  for TN:  1803241_145-UMA loop count1423
# Shortening  for TN:  1803241_145-UnschedMaint loop count1424
# Shortening  for TN:  1803241_145-MA loop count1425
# Shortening  for TN:  1803241_145-MAF loop count1426
# Shortening  for TN:  1803242_140-EMA loop count1427
# Shortening  for TN:  1803242_140-SchedMaint loop count1428
# Shortening  for TN:  1803242_140-UMA loop count1429
# Shortening  for TN:  1803242_140-UnschedMaint loop count1430
# Shortening  for TN:  1803242_140-MA loop count1431
# Shortening  for TN:  1803242_140-MAF loop count1432
# Shortening  for TN:  1803243_131-EMA loop count1433
# Shortening  for TN:  1803243_131-SchedMaint loop count1434
# Shortening  for TN:  1803243_131-UMA loop count1435
# Shortening  for TN:  1803243_131-UnschedMaint loop count1436
# Shortening  for TN:  1803243_131-MAF loop count1437
# Shortening  for TN:  1803243_131-MA loop count1438
# Shortening  for TN:  1803244_177-SchedMaint loop count1439
# Shortening  for TN:  1803244_177-EMA loop count1440
# Shortening  for TN:  1803244_177-UMA loop count1441
# Shortening  for TN:  1803244_177-UnschedMaint loop count1442
# Shortening  for TN:  1803244_177-MA loop count1443
# Shortening  for TN:  1803244_177-MAF loop count1444
# Shortening  for TN:  1803245_173-SchedMaint loop count1445
# Shortening  for TN:  1803245_173-UMA loop count1446
# Shortening  for TN:  1803245_173-UnschedMaint loop count1447
# Shortening  for TN:  1803245_173-EMA loop count1448
# Shortening  for TN:  1803246_199-SchedMaint loop count1449
# Shortening  for TN:  1803246_199-UMA loop count1450
# Shortening  for TN:  1803246_199-UnschedMaint loop count1451
# Shortening  for TN:  1803246_199-EMA loop count1452
# Shortening  for TN:  1803247_184-EMA loop count1453
# Shortening  for TN:  1803247_184-SchedMaint loop count1454
# Shortening  for TN:  1803247_184-UMA loop count1455
# Shortening  for TN:  1803247_184-UnschedMaint loop count1456
# Shortening  for TN:  1803247_184-MA loop count1457
# Shortening  for TN:  1803247_184-MAF loop count1458
# Shortening  for TN:  1803248_147-SchedMaint loop count1459
# Shortening  for TN:  1803248_147-UMA loop count1460
# Shortening  for TN:  1803248_147-UnschedMaint loop count1461
# Shortening  for TN:  1803248_147-EMA loop count1462
# Shortening  for TN:  1803249_212-SchedMaint loop count1463
# Shortening  for TN:  1803249_212-UMA loop count1464
# Shortening  for TN:  1803249_212-UnschedMaint loop count1465
# Shortening  for TN:  1803249_212-EMA loop count1466
# Shortening  for TN:  1803249_212-MA loop count1467
# Shortening  for TN:  1803249_212-MAF loop count1468
# Shortening  for TN:  1903250_207-SchedMaint loop count1469
# Shortening  for TN:  1903250_207-UMA loop count1470
# Shortening  for TN:  1903250_207-UnschedMaint loop count1471
# Shortening  for TN:  1903250_207-EMA loop count1472
# Shortening  for TN:  1903250_207-MA loop count1473
# Shortening  for TN:  1903250_207-MAF loop count1474
# Shortening  for TN:  1903251_163-SchedMaint loop count1475
# Shortening  for TN:  1903251_163-EMA loop count1476
# Shortening  for TN:  1903251_163-UMA loop count1477
# Shortening  for TN:  1903251_163-UnschedMaint loop count1478
# Shortening  for TN:  1903251_163-MA loop count1479
# Shortening  for TN:  1903251_163-MAF loop count1480
# Shortening  for TN:  1903254_190-SchedMaint loop count1481
# Shortening  for TN:  1903254_190-UMA loop count1482
# Shortening  for TN:  1903254_190-UnschedMaint loop count1483
# Shortening  for TN:  1903254_190-EMA loop count1484
# Shortening  for TN:  1903256_210-SchedMaint loop count1485
# Shortening  for TN:  1903256_210-UMA loop count1486
# Shortening  for TN:  1903256_210-UnschedMaint loop count1487
# Shortening  for TN:  1903256_210-EMA loop count1488
# Shortening  for TN:  1903256_210-MAF loop count1489
# Shortening  for TN:  1903256_210-MA loop count1490

# %%
# Looking at the Data generated. So we can verify it does what we think it does.
# Note now, the only classes with 1 event have been shortened all the way to 2 digits.  Everything else converged somewhere up the chain.
Shortened_RFGs[(Shortened_RFGs['tn-class']=="1009003_2-UnschedMaint")]['RFG'].value_counts()
# Out:
# 05A01H    59
# 09W       26
# 02B22     17
# 02C15     17
# 04A       17
#           ..
# 09C04A     2
# 36         1
# 15         1
# 12         1
# 83         1
# Name: RFG, Length: 220, dtype: int64

# %%
####################################################
# Find the time between events *of the same class*
# Add those diff's to the frame


TimeDiffs = Shortened_RFGs.copy()

# Set an identifier for a TailNumber, RFG and EventClass combined
TimeDiffs['tn_rfg_class'] = TimeDiffs['NewTailNumber'].astype(str)+"_" + TimeDiffs['RFG'] + "_" + TimeDiffs['EventClass']
TimeDiffs.sort_values(by=['tn_rfg_class','EVENT_DATE_TIME','RELEVANT_BEG_AGE'],ignore_index=True,inplace=True) 

# Groupby the Identifier and then take the time differences.  
TimeDiffs['TimeSinceLast'] = TimeDiffs.groupby(['tn_rfg_class'])['RELEVANT_BEG_AGE'].diff()  # Now that they're grouped by TN/RFG/CLASS and sorted by Date/Hours... I can find the difference intervals between those events
save_df(TimeDiffs)

# %%
# Debugging/validation section. Uncomment/change one at a time to take a look/browse the data.
# 
# Random TailNumber
TimeDiffs[TimeDiffs['TailNumber'].astype(str) == '1009002']

# Random EventClass
# TimeDiffs[(TimeDiffs['TailNumber'].astype(str) == '1009002') & (TimeDiffs['EventClass'] == 'UnschedMaint')]

# Random RFG
# TimeDiffs[(TimeDiffs['TailNumber'].astype(str) == '1009002') & (TimeDiffs['EventClass'] == 'UnschedMaint') & (TimeDiffs['RFG'] == '02A15C')]

# Also note you could have just
# TimeDiffs[TimeDiffs['tn_rfg_class'] == '1009002_152_02A15C_UnschedMaint']

# The Math checks out...  (TimeSinceLast is accurate)
# Note the dups (the Zeros...... )

# Also note Negatives :/  
# TimeDiffs[TimeDiffs['TimeSinceLast']<0]

# Pick one  
# TimeDiffs[TimeDiffs['tn_rfg_class'] == '1903256_210_09A01_SchedMaint']  #Ugh.  But we'll deal and move on.

# %%
###########################
#   Let's filter out the start times and 'mistake' times (where time is negative)  (As we can tell above this is going to give 'some' bad data.  We can fix this)

Weibulldata = TimeDiffs.copy()

#Weibulldata = Weibulldata.reset_index(drop=True)  # just keep mashing that button.
Weibulldata = Weibulldata[(Weibulldata['TimeSinceLast'].notnull()) & (Weibulldata['TimeSinceLast'] > 0)]  # ouch.. just included the outliers
Weibulldata = Weibulldata.reset_index(drop=True)


# Here is where we start bringing together the RFG/Classes so now we can see the size of the datasets
Weibulldata['rfg-class'] = Weibulldata['RFG'].astype(str) + "_" + Weibulldata['EventClass'].astype(str)


#Weibulldata = Weibulldata[Weibulldata['rfg-class'].map(Weibulldata['rfg-class'].value_counts()) >= 5] 
sample = Weibulldata['rfg-class'].value_counts()
Weibulldata = Weibulldata.loc[Weibulldata['rfg-class'].isin(sample[sample.gt(4)].index)] # Greater than or equal to 5

#Weibulldata = Weibulldata[Weibulldata['TimeSinceLast'] > 0] # Thinking this isn't the best answer but it cleans the data some
Weibulldata = Weibulldata.reset_index(drop=True)
Weibulldata['rfg-class'].value_counts() # Tada
# Out:
# 00_SchedMaint         22193
# 05A02_SchedMaint      10360
# 16S_SchedMaint         7995
# 18A02_SchedMaint       7819
# 04A_SchedMaint         6617
#                       ...
# 15C07_UMA                 5
# 15C07_UnschedMaint        5
# 05B01_EMA                 5
# 19D02_UMA                 5
# 17_EMA                    5
# Name: rfg-class, Length: 1591, dtype: int64

# %%
# Examine just a bit
#
# Random RFG-Class
Weibulldata[Weibulldata['rfg-class'] == '04A_SchedMaint'] 

# Pick one of the events and map it back to the helicopter data
TimeDiffs[TimeDiffs['tn_rfg_class'] == '1009002_152_04A_SchedMaint']

# Take it all the way back to ALL_DATA
#ALL_DATA[(ALL_DATA['EI_SN']=='1009002') & (ALL_DATA['RFG'] == '04A')]
# Out:
#                             Key13 / RFG / EventClass  \
# 2563  AH-64E-1009002-04A-SchedMaint-20170104-A-00002
# 2564  AH-64E-1009002-04A-SchedMaint-20170117-A-00001
# 2565  AH-64E-1009002-04A-SchedMaint-20170127-A-00002
# 2566  AH-64E-1009002-04A-SchedMaint-20170209-A-00001
# 2567  AH-64E-1009002-04A-SchedMaint-20170318-A-00002
# ...                                              ...
# 2673  AH-64E-1009002-04A-SchedMaint-20210205-A-00100
# 2674  AH-64E-1009002-04A-SchedMaint-20210221-A-00100
# 2675  AH-64E-1009002-04A-SchedMaint-20210306-A-00200
# 2676  AH-64E-1009002-04A-SchedMaint-20210318-A-00110
# 2677  AH-64E-1009002-04A-SchedMaint-20210427-A-00110
#
#                                 KEY13 TailNumber NewTailNumber  \
# 2563  AH-64E-1009002-20170104-A-00002    1009002   1009002_152
# 2564  AH-64E-1009002-20170117-A-00001    1009002   1009002_152
# 2565  AH-64E-1009002-20170127-A-00002    1009002   1009002_152
# 2566  AH-64E-1009002-20170209-A-00001    1009002   1009002_152
# 2567  AH-64E-1009002-20170318-A-00002    1009002   1009002_152
# ...                               ...        ...           ...
# 2673  AH-64E-1009002-20210205-A-00100    1009002   1009002_152
# 2674  AH-64E-1009002-20210221-A-00100    1009002   1009002_152
# 2675  AH-64E-1009002-20210306-A-00200    1009002   1009002_152
# 2676  AH-64E-1009002-20210318-A-00110    1009002   1009002_152
# 2677  AH-64E-1009002-20210427-A-00110    1009002   1009002_152
#
#                     tn-class EVENT_DATE_TIME  RELEVANT_BEG_AGE  TMMH  TMEN  \
# 2563  1009002_152-SchedMaint      2017-01-04       5631.200195   0.1   1.0
# 2564  1009002_152-SchedMaint      2017-01-17       5639.600098   0.1   1.0
# 2565  1009002_152-SchedMaint      2017-01-27       5646.299805   1.0   1.0
# 2566  1009002_152-SchedMaint      2017-02-09       5647.100098   1.0   1.0
# 2567  1009002_152-SchedMaint      2017-03-18       5683.700195   0.5   1.0
# ...                      ...             ...               ...   ...   ...
# 2673  1009002_152-SchedMaint      2021-02-05       6206.799805   3.0   1.0
# 2674  1009002_152-SchedMaint      2021-02-21       6206.799805   0.3   1.0
# 2675  1009002_152-SchedMaint      2021-03-06       6209.299805   0.3   1.0
# 2676  1009002_152-SchedMaint      2021-03-18       6228.399902   0.2   1.0
# 2677  1009002_152-SchedMaint      2021-04-27       6249.799805   0.2   1.0
#
#       TIMH  RFG  EventClass  lengthRFG                tn_rfg_class  \
# 2563   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2564   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2565   0.1  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2566   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2567   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# ...    ...  ...         ...        ...                         ...
# 2673   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2674   0.3  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2675   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2676   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
# 2677   0.0  04A  SchedMaint        3.0  1009002_152_04A_SchedMaint
#
#       TimeSinceLast
# 2563            NaN
# 2564       8.399902
# 2565       6.699707
# 2566       0.800293
# 2567      36.600098
# ...             ...
# 2673       3.099609
# 2674       0.000000
# 2675       2.500000
# 2676      19.100098
# 2677      21.399902
#
# [115 rows x 15 columns]

# %%
############################################################
# Add Some stats!
###########################################################

lstSHAPE = []       # Initialize the list
lstLOCATION = []    # Initialize the list
lstSCALE = []       # Initialize the list
lstMEAN = []        # Initialize the list
lstVAR = []         # Initialize the list
lstSTDEV = []       # Initialize the list
lstDelete = []      # Initialize the list
lstDiff = []        # Initialize the list
lstStat_Pearson = []        # Initialize the list
lstPVal_Pearson = []        # Initialize the listde
lstStat_LogLike = []        # Initialize the list
lstPVal_LogLike = []        # Initialize the list
lstStat_FreeTuk = []        # Initialize the list
lstPVal_FreeTuk = []        # Initialize the list
lstStat_ModLogLike = []        # Initialize the list
lstPVal_ModLogLike = []        # Initialize the list
lstStat_Neyman = []        # Initialize the list
lstPVal_Neyman = []        # Initialize the list
lstStat_CRead = []        # Initialize the list
lstPVal_CRead = []        # Initialize the list
datapoints = []  
lstrfg_class = []   
WeibullDataCount = pd.DataFrame()
round = 1
print ("There will be " + str(len(Weibulldata['rfg-class'].unique())) + ' rounds' )
for rfg_class in Weibulldata['rfg-class'].unique():
    print('Round: ' + str(round))
    round = round + 1
    lstDiff = Weibulldata[Weibulldata['rfg-class']==rfg_class]['TimeSinceLast'].values 
    # print(lstDiff)
    # print(lstDiff.size)
    datapoints.append(lstDiff.size)
    shape, loc, scale = weibull_min.fit(lstDiff)
    Mean, Variance = weibull_min.stats(shape, scale=scale, moments='mv')
    StDev = weibull_min.std(shape, scale=scale)
    Pearson = power_divergence(lstDiff, lambda_='pearson')
    LogLike = power_divergence(lstDiff, lambda_='log-likelihood')
    FreeTuk = power_divergence(lstDiff, lambda_='freeman-tukey')
    ModLogLike = power_divergence(lstDiff, lambda_='mod-log-likelihood')
    Neyman = power_divergence(lstDiff, lambda_='neyman')
    CRead = power_divergence(lstDiff, lambda_='cressie-read')
    lstrfg_class.append(rfg_class)
    lstSHAPE.append(shape)
    lstLOCATION.append(loc)
    lstSCALE.append(scale)
    lstMEAN.append(Mean)
    lstVAR.append(Variance)
    lstSTDEV.append(StDev)
    lstStat_Pearson.append(Pearson[0])
    lstPVal_Pearson.append(Pearson[1])
    lstStat_LogLike.append(LogLike[0])
    lstPVal_LogLike.append(LogLike[1])
    lstStat_FreeTuk.append(FreeTuk[0])
    lstPVal_FreeTuk.append(FreeTuk[1])
    lstStat_ModLogLike.append(ModLogLike[0])
    lstPVal_ModLogLike.append(ModLogLike[1])
    lstStat_Neyman.append(Neyman[0])
    lstPVal_Neyman.append(Neyman[1])
    lstStat_CRead.append(CRead[0])
    lstPVal_CRead.append(CRead[1])
WeibullDataCount['RFG-Class'] = lstrfg_class
WeibullDataCount['Datapoints'] = datapoints
WeibullDataCount['Shape'] = lstSHAPE
WeibullDataCount['Location'] = lstLOCATION
WeibullDataCount['Scale'] = lstSCALE
WeibullDataCount['Mean'] = lstMEAN
WeibullDataCount['Variance'] = lstVAR
WeibullDataCount['St. Dev.'] = lstSTDEV
#WeibullDataCount['Zero Count'] = listZeroCounts     I can add this back in but getting this out there for the time being.
WeibullDataCount['Pearson_CRstat'] = lstStat_Pearson
WeibullDataCount['Pearson_Pvalue'] = lstPVal_Pearson
WeibullDataCount['LogLikelihood_CRstat'] = lstStat_LogLike
WeibullDataCount['LogLikelihood_Pvalue'] = lstPVal_LogLike
WeibullDataCount['FreemanTukey_CRstat'] = lstStat_FreeTuk
WeibullDataCount['FreemanTukey_Pvalue'] = lstPVal_FreeTuk
WeibullDataCount['ModLogLikelihood_CRstat'] = lstStat_ModLogLike
WeibullDataCount['ModLogLikelihood_Pvalue'] = lstPVal_ModLogLike
WeibullDataCount['Neyman_CRstat'] = lstStat_Neyman
WeibullDataCount['Neyman_Pvalue'] = lstPVal_Neyman
WeibullDataCount['CressieRead_CRstat'] = lstStat_CRead
WeibullDataCount['CressieRead_Pvalue'] = lstPVal_CRead
#WeibullDataCount = WeibullDataCount.drop(WeibullParams.index[lstDelete]) # This (hopefully) will do nothing, due to data preprocessing
WeibullDataCount = WeibullDataCount.sort_values(['RFG-Class'])
WeibullDataCount = WeibullDataCount.reset_index(drop=True)
WeibullDataCount.name = 'WeibullDataCount'
save_df(WeibullDataCount)
# Out:
# There will be 1591 rounds
# Round: 1
# Round: 2
# Round: 3
# Round: 4
# Round: 5
# Round: 6
# Round: 7
# Round: 8
# Round: 9
# Round: 10
# Round: 11
# Round: 12
# Round: 13
# Round: 14
# Round: 15
# Round: 16
# Round: 17
# Round: 18
# Round: 19
# Round: 20
# Round: 21
# Round: 22
# Round: 23
# Round: 24
# Round: 25
# Round: 26
# Round: 27
# Round: 28
# Round: 29
# Round: 30
# Round: 31
# Round: 32
# Round: 33
# Round: 34
# Round: 35
# Round: 36
# Round: 37
# Round: 38
# Round: 39
# Round: 40
# Round: 41
# Round: 42
# Round: 43
# Round: 44
# Round: 45
# Round: 46
# Round: 47
# Round: 48
# Round: 49
# Round: 50
# Round: 51
# Round: 52
# Round: 53
# Round: 54
# Round: 55
# Round: 56
# Round: 57
# Round: 58
# Round: 59
# Round: 60
# Round: 61
# Round: 62
# Round: 63
# Round: 64
# Round: 65
# Round: 66
# Round: 67
# Round: 68
# Round: 69
# 6         9.682911e-61
# 7         1.412977e-38
# 8         1.412977e-38
# 9        1.340749e-297
# 10       1.340749e-297
# 11        0.000000e+00
# 12        0.000000e+00
# 13       6.808572e-131
# 14        0.000000e+00

# %%
Weibulldata['rfg-class'] = Weibulldata['RFG'].astype(str) + "_" + Weibulldata['EventClass'].astype(str)
Weibulldata[Weibulldata['rfg-class'] == '02A01C02_UMA']
#TN_Intervals[TN_Intervals['EI_SN'] == 1603086]
# Out:
#                             Key13 / RFG / EventClass  \
# 13451   AH-64E-1009005-02A01C02-UMA-20160328-A-00006
# 69781   AH-64E-1109020-02A01C02-UMA-20180905-A-00025
# 136546  AH-64E-1603084-02A01C02-UMA-20200526-A-00250
# 144963  AH-64E-1603090-02A01C02-UMA-20200202-A-00130
# 162634  AH-64E-1603101-02A01C02-UMA-20200303-A-00200
# 172610  AH-64E-1603112-02A01C02-UMA-20200331-A-00310
#
#                                   KEY13 TailNumber NewTailNumber  \
# 13451   AH-64E-1009005-20160328-A-00006    1009005     1009005_7
# 69781   AH-64E-1109020-20180905-A-00025    1109020    1109020_42
# 136546  AH-64E-1603084-20200526-A-00250    1603084    1603084_77
# 144963  AH-64E-1603090-20200202-A-00130    1603090    1603090_87
# 162634  AH-64E-1603101-20200303-A-00200    1603101    1603101_95
# 172610  AH-64E-1603112-20200331-A-00310    1603112   1603112_167
#
#                tn-class EVENT_DATE_TIME  RELEVANT_BEG_AGE  TMMH  TMEN  TIMH  \
# 13451     1009005_7-UMA      2016-03-28       4682.500000   2.0   1.0   0.1
# 69781    1109020_42-UMA      2018-09-05       6539.500000   0.2   1.0   0.0
# 136546   1603084_77-UMA      2020-05-26        774.000000   4.0   4.0   1.0
# 144963   1603090_87-UMA      2020-02-02        883.200012   0.2   1.0   0.0
# 162634   1603101_95-UMA      2020-03-03        784.299988   4.0   1.0   1.0
# 172610  1603112_167-UMA      2020-03-31        484.799988   0.1   1.0   0.2
#
#              RFG EventClass  lengthRFG              tn_rfg_class  \
# 13451   02A01C02        UMA        8.0    1009005_7_02A01C02_UMA
# 69781   02A01C02        UMA        8.0   1109020_42_02A01C02_UMA
# 136546  02A01C02        UMA        8.0   1603084_77_02A01C02_UMA
# 144963  02A01C02        UMA        8.0   1603090_87_02A01C02_UMA
# 162634  02A01C02        UMA        8.0   1603101_95_02A01C02_UMA
# 172610  02A01C02        UMA        8.0  1603112_167_02A01C02_UMA
#
#         TimeSinceLast     rfg-class
# 13451      166.100098  02A01C02_UMA
# 69781       32.200195  02A01C02_UMA
# 136546     197.599976  02A01C02_UMA
# 144963      77.299988  02A01C02_UMA
# 162634      44.299988  02A01C02_UMA
# 172610      26.599976  02A01C02_UMA

# %%
lstDiff = Weibulldata[Weibulldata['rfg-class']=='02A01C02_UMA']['TimeSinceLast'].values
print(weibull_min.fit(lstDiff))
print(weibull_min.fit(lstDiff, loc=0, method="MLE"))
# Out:
# (0.28353150373941416, 26.599975585937496, 79.46402743869263)
# (0.6104557313290632, 26.599975585937493, 59.49420299160256)
